# %%
import numpy as np
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import re
from scipy import interpolate
import manipulate_text as mt
import copy
import itertools
import argparse
import numpy.ma as ma
from scipy.optimize import minimize
import time
from scipy.stats import norm

# %%
#define relevant paths and names
script_path = os.getcwd()
base_path =  script_path.split('scripts')[0]
fits_path = base_path.split('Secondary_radiation')[0] + 'synchrotron_data/'
fits_name = 'm31cm3nthnew.ss.90sec.fits'

# %%
def get_data_and_info(fits_path, fits_name):
    #extract data and information about data
    hdul = fits.open(fits_path+fits_name)
    data_uJ = hdul[0].data[0]
    data = data_uJ/1000 #mJ/beam
    hdr = hdul[0].header
    dlt_N_deg = abs(hdr['CDELT1'])
    dlt_n_deg = abs(hdr['CDELT2'])
    N = hdr['NAXIS1']
    n = hdr['NAXIS2']
    nu_data = hdr['CRVAL3']
    nu_BW = hdr['CDELT3']
    HPBW_deg = hdr['BMIN']
    return data, dlt_N_deg, dlt_n_deg, N, n, HPBW_deg, nu_data, nu_BW 

def make_coords(N, n, dlt_N, dlt_n, loc='centered'):
    if loc=='centered':
        ax_N_unit = np.linspace(-(N-1)/2, (N-1)/2, N)
        ax_n_unit = np.linspace(-(n-1)/2, (n-1)/2, n)
    elif loc=='edges':
        ax_N_unit = np.linspace(-N/2, N/2, N+1)
        ax_n_unit = np.linspace(-n/2, n/2, n+1)
    return dlt_N*ax_N_unit, dlt_n*ax_n_unit

def gen_fake_data(beam_cut, frac, sigma_rms, sigma_BW, N, n, dlt_N, dlt_n):
    num_beams = beam_cut+1
    
    #create coords for data
    ax_N, ax_n = make_coords(N, n, dlt_N, dlt_n)
    AX_N, AX_n = np.meshgrid(ax_N, ax_n)
    
    #create coords for sources
    dlt_N_source = dlt_N/frac
    dlt_n_source = dlt_N_source
    fov_N = N*dlt_N
    print('fov N: ' + str(fov_N))
    fov_n = n*dlt_n
    print('fov n: ' + str(fov_n))
    fov_N_source = fov_N+2*num_beams*sigma_BW
    print('fov N source: ' + str(fov_N_source))
    fov_n_source = fov_n+2*num_beams*sigma_BW
    print('fov n source: ' + str(fov_n_source))
    N_source = int(np.round(fov_N_source/dlt_N_source))
    print('N source: ' + str(N_source))
    n_source = int(np.round(fov_n_source/dlt_n_source))
    print('n source: ' + str(n_source))
    fov_N_source = N_source*dlt_N_source
    fov_n_source = n_source*dlt_n_source
    ax_N_source, ax_n_source = make_coords(N_source, n_source, dlt_N_source, dlt_n_source)
    AX_N_SOURCE, AX_n_SOURCE = np.meshgrid(ax_N_source, ax_n_source)
    #smaller rms noise in the central lxb region where l and b are in degrees
    l = 2/3
    b = 2/3
    outside = np.logical_or(np.abs(AX_N_SOURCE)>(l/2)*np.pi/180, np.abs(AX_n_SOURCE)>(b/2)*np.pi/180)
    inside = np.logical_not(outside)
    noise = sigma_rms[-1]*outside + sigma_rms[0]*inside
    #generate fake data
    z = np.random.normal(size=(n_source, N_source))
    data_gen = 0*AX_N
    for i in range(n_source):
        for j in range(N_source):
            loc = (ax_n_source[i], ax_N_source[j])
            start_N = np.searchsorted(ax_N, loc[1]-beam_cut*sigma_BW, side='left')
            end_N = np.searchsorted(ax_N, loc[1]+beam_cut*sigma_BW, side='left')
            start_n = np.searchsorted(ax_n, loc[0]-beam_cut*sigma_BW, side='left')
            end_n = np.searchsorted(ax_n, loc[0]+beam_cut*sigma_BW, side='left')
            beam = dlt_N_source*noise[i,j]/(np.sqrt(np.pi)*sigma_BW)*z[i, j] \
                *np.exp(-((AX_N[start_n:end_n, start_N:end_N]-ax_N_source[j])**2+(AX_n[start_n:end_n, start_N:end_N]-ax_n_source[i])**2)/(2*sigma_BW**2))
            data_gen[start_n:end_n, start_N:end_N] += beam
    return data_gen, AX_N, AX_n

def gen_templates(run, nu_data, omega_beam, AX_N, AX_n):
    n, N = AX_N.shape
    #bring in variables from the run
    DA = run['DA']
    txt_file_name = run['file_name']
    nrho = run['nrho']
    nnu = run['nnu']
    sigmav_bench = run['sigma_v']
    rho_range = run['rho_range']
    nu_range = run['nu_range']
    
    #process run variables
    array_file_name = txt_file_name.split('_info')[0] + '.npy'
    m = re.search('[0-9]{4}_', array_file_name)
    out_type = array_file_name.split('.npy')[0].split(m.group(0))[-1]
    nu_v = np.logspace(np.log10(nu_range[0]), np.log10(nu_range[1]), nnu)
    rho_v = np.linspace(rho_range[0], rho_range[1], nrho)
    theta_v = np.arcsin(rho_v/np.sqrt(rho_v**2+DA**2))
    thetatheta, nunu = np.meshgrid(theta_v, nu_v)
    
    #load flux and change units
    nu_dSdth = np.load(base_path + out_type + '/' + array_file_name) #erg cm^-2 s^-1 rad^-1
    dS_dnudOmega = ((10**26/nunu)*nu_dSdth/(2*np.pi*np.sin(thetatheta))).astype(np.float64) #mJy/Sr
    rho_v_low = np.linspace(0, rho_range[0], 5)
    theta_v_low = np.arcsin(rho_v_low/np.sqrt(rho_v_low**2+DA**2))
    thetatheta_low, nunu_low = np.meshgrid(theta_v_low, nu_v)
    flux_low = 0*thetatheta_low
    
    #find max synch frequency index and extrapolate to rho=0
    delta_theta = (theta_v[1]-theta_v[0])/100
    domain = min(5,len(theta_v))
    for i in range(dS_dnudOmega.shape[0]):
        zs = np.where(dS_dnudOmega[i] == 0)[0]
        if len(zs) == nrho:
            nu_fin_ind = i #max frequency index + 1
            break
        else:
            for elem in zs:
                dS_dnudOmega[i, elem] = 1e-300
            oned_interp_nu = interpolate.interp1d(theta_v[0:domain], dS_dnudOmega[i][0:domain], kind = 'cubic')
            f_pr = (oned_interp_nu(theta_v[0]+delta_theta) - oned_interp_nu(theta_v[0]))/delta_theta
            f_prpr = f_pr/theta_v[0]
            f_0 = oned_interp_nu(theta_v[0])-f_prpr*theta_v[0]**2/2
            flux_low[i] = f_0+f_prpr*theta_v_low**2/2
    #combine low rho solution with main solution
    dS_dnudOmega_extrap = np.hstack((flux_low[:, :-1], dS_dnudOmega))
    theta_v_extrap = np.hstack((theta_v_low[:-1], theta_v))
    
    ln_dS_dnudOmega_extrap = np.log(dS_dnudOmega_extrap[0:nu_fin_ind])
    ln_dS_dnudOmega_interp = interpolate.interp2d(theta_v_extrap, nu_v[0:nu_fin_ind], ln_dS_dnudOmega_extrap[0:nu_fin_ind], kind='cubic')
    
    def dS_dnudOmega_cart(th_x, th_y, nu):
        return np.exp(ln_dS_dnudOmega_interp(np.sqrt(th_x**2+th_y**2), nu))
    
    #generate expected signal flux per beam in each pixel. The real way to do this is
    #to convolve real signal with beam using sig_meas function. This is slow and after testing
    #on a few points it seems that dS_dndOmega*Omega_beam is a good approximation.
    signal_beam = np.zeros((n,N)) 
    for i in range(signal_beam.shape[0]):
        for j in range(signal_beam.shape[1]):    
            signal_beam[i, j] = dS_dnudOmega_cart(AX_N[i, j], AX_n[i, j], nu_data)*omega_beam
    back_beam = np.ones((n, N))
    return signal_beam, back_beam

def sort_runs(mx_set, D0_set, args=None, rtrn='inds'):
    D0_vals = np.sort(np.unique(D0_set))
    ind_set = []
    for D0_val in D0_vals:
        ind_D0val = np.where(D0_set==D0_val)[0]
        p_D0val = np.argsort(mx_set[ind_D0val])
        ind_set.append(ind_D0val[p_D0val])
    ind_set_tup = tuple(ind_set)
    ind_full = np.hstack(ind_set_tup)
    if rtrn == 'inds':
        return ind_full
    elif rtrn == 'arrs':
        if args==None:
            return mx_set[ind_full], D0_set[ind_full]
        else:
            return mx_set[ind_full], D0_set[ind_full], tuple(args[i][ind_full] for i in range(len(args)))
        
#coords = (x, y)                                                                                                                                          
#ellipse_params = (r, a, thickness/2)  
def create_mask(THETA, th_range, ps_ind=None, rl=None, coords=None, ellipse_params=None, data=None,  sigma_rms=None, num_sigma_rms=None, sigma_BW=None, num_sigma_BW=None, dlt=None,\
 method='azimuthally_sym'):
    m0 = 0*THETA==0
    m1 = m0
    m2 = m0
    m3 = m0
    if ps_ind is not None:
        m0[ps_ind]=False
    if method=='azimuthally_sym':
        m1 = np.logical_and(THETA>th_range[0], THETA<th_range[1])
    elif method=='ellipse_and_azimuthally_sym':
        m1 = np.logical_and(THETA>th_range[0], THETA<th_range[1])
        elliptic_d = np.sqrt(coords[0]**2+(ellipse_params[0]**2)*coords[1]**2)
        m2 = np.abs(elliptic_d-ellipse_params[1])>ellipse_params[2]
    if rl=='right':
        m3[np.where(AX_N>=0)] = False
    elif rl=='left':
        m3[np.where(AX_N<=0)] = False
    return m0*m1*m2*m3

def f(x, w):
    elliptic_d = np.sqrt(x[0]**2+w[2]**2*x[1]**2)
    return w[0]+w[1]*np.exp(-(elliptic_d-w[3])**2/(2*w[4]**2))

def chi2(w, *args):
    model = f(args[1], w)
    return np.sum(((args[0]-model)**2/args[2]**2)*args[3])

def find_test_stats(resid, signal, background, sigma_rms, mask, this_ws, this_dw, this_chi_sb_sb, sigmav, sigmav_bench=2.2e-26):
    this_w0b = this_ws
    this_chi_b_b = this_chi_sb_sb
    this_w0s = this_ws+(sigmav/sigmav_bench)*this_dw
    this_wb = this_ws-(sigmav/sigmav_bench)*this_dw
    this_chi_b_sb = np.sum(mask*(resid+(sigmav/sigmav_bench)*signal-this_w0s*background)**2/(sigma_rms**2))
    this_chi_sb_b = np.sum(mask*(resid-(sigmav/sigmav_bench)*signal-this_wb*background)**2/(sigma_rms**2))
    this_delta_chi_b = this_chi_sb_b-this_chi_b_b
    this_delta_chi_sb = this_chi_sb_sb-this_chi_b_sb 
    return this_ws, this_w0b, this_w0s, this_wb, this_chi_sb_b, this_chi_b_sb, this_delta_chi_b, this_delta_chi_sb

def remove_ps(data, THETA, cent, ann1, ann2, thresh):
    #find center index
    ind0 = np.where(THETA==0)
    indy0 = ind0[0][0]
    indx0 = ind0[1][0]

    #find indices of annulus
    ind_ann0 = np.where(np.logical_and(THETA>ann1, THETA<ann2))
    dlt_ind_ann = (ind_ann0[0]-indy0, ind_ann0[1]-indx0)

    #find indices of center
    ind_cent0 = np.where(THETA<cent)
    dlt_ind_cent = (ind_cent0[0]-indy0, ind_cent0[1]-indx0)
    
    #prepare for for-loops
    sh = data.shape
    mask_indx = []
    mask_indy = []
    
    #iterate over each pixel, putting the circle and annulus centered over the pixel and computing the average
    #intensity in each. If the circle has an average intensity larger than the annulus by a certain amount
    #then store the indices of the circle for masking
    for i in range(sh[0]):
        #print('i: ', i)
        for j in range(sh[1]):
            ind_of_ind = [k for k in range(len(dlt_ind_ann[0])) \
                                  if j+dlt_ind_ann[1][k] < N and j+dlt_ind_ann[1][k] >= 0\
                                 and i+dlt_ind_ann[0][k] < n and i+dlt_ind_ann[0][k] >= 0]
            ind_ann_x = [int(j+dlt_ind_ann[1][ind]) for ind in ind_of_ind]
            ind_ann_y = [int(i+dlt_ind_ann[0][ind]) for ind in ind_of_ind]
            num_ann = len(ind_of_ind)

            ind_of_ind_cent = [k for k in range(len(dlt_ind_cent[0])) \
                                  if j+dlt_ind_cent[1][k] < N and j+dlt_ind_cent[1][k] >= 0\
                                 and i+dlt_ind_cent[0][k] < n and i+dlt_ind_cent[0][k] >= 0]
            ind_cent_x = [int(j+dlt_ind_cent[1][ind]) for ind in ind_of_ind_cent]
            ind_cent_y = [int(i+dlt_ind_cent[0][ind]) for ind in ind_of_ind_cent]
            num_cent = len(ind_of_ind_cent)

            #compute average intensity in annulus and center
            I_center = np.sum(data[(ind_cent_y, ind_cent_x)])/num_cent
            I_ann = np.sum(data[(ind_ann_y, ind_ann_x)])/num_ann

            if I_center > thresh[i,j]+I_ann: #or I_center < I_ann-thresh[i,j]: (include if voids should be masked)
                mask_indy += list(ind_cent_y)
                mask_indx += list(ind_cent_x)
                
    #remove repeated pairs of indices from the list of indices
    mask_inds_raw = np.array([mask_indy, mask_indx])
    print('raw indices found')
    mask_inds = np.unique(mask_inds_raw, axis=1)
    
    #plot data with masked indices indicated with scatter points
    #plt.imshow(data)
    #plt.scatter(mask_inds[1], mask_inds[0], s=2, color='r')
    
    return tuple(mask_inds)

# %%
#extract info about data
data, dlt_N_deg, dlt_n_deg, N, n, HPBW_deg, nu_data, nu_BW = get_data_and_info(fits_path, fits_name)
dlt_N = dlt_N_deg*np.pi/180
dlt_n = dlt_n_deg*np.pi/180
HPBW = HPBW_deg*np.pi/180
sigma_BW = HPBW/(2*np.sqrt(2*np.log(2)))
omega_beam = 2*np.pi*sigma_BW**2
print('real data info extracted')
# Out:
# real data info extracted

# %%
#create coords for data
ax_N, ax_n = make_coords(N, n, dlt_N, dlt_n)
AX_N, AX_n = np.meshgrid(ax_N, ax_n)
THETA = np.sqrt(AX_N**2+AX_n**2)
sigma_rms = [0.25, 0.3]
l = 2/3
b = 2/3
outside = np.logical_or(np.abs(AX_N)>(l/2)*np.pi/180, np.abs(AX_n)>(b/2)*np.pi/180)
inside = np.logical_not(outside)
noise = sigma_rms[-1]*outside + sigma_rms[0]*inside

# %%
#define dimensionless hyperparams
dless_rad0 = .75
dless_rad1 = 2.25
dless_rad2 = 2.5
num_sigmas = 4

#compute physical hyperparams
cent = dless_rad0*HPBW/2
ann1 = dless_rad1*HPBW/2
ann2 = dless_rad2*HPBW/2
thresh = num_sigmas*noise

mask_inds = remove_ps(data, THETA, cent, ann1, ann2, thresh)
# Out:
# raw indices found

# %%
omega_pix = dlt_N*dlt_n
pix_per_beam = omega_beam/omega_pix
min_pix = pix_per_beam
this_mask = create_mask(THETA, [0, np.pi], ps_ind=mask_inds, coords=(AX_N, AX_n))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.imshow(ma.array(data, mask=np.logical_not(this_mask)), vmin=np.min(data), vmax = np.max(data))
#plt.title(r'ellipse mask thickness = '+ '{:.2e}'.format(thickness) + r' rad')
plt.colorbar(orientation='horizontal')
#plt.savefig(base_path+'figs/ps_mask_data.pdf')
num_bins = 100
th_bins = np.linspace(0, np.max(THETA), num_bins+1)
flux_bin = np.zeros(num_bins)
pix_bin = np.zeros(num_bins)
er_flux = np.zeros(num_bins)
for i in range(num_bins):
    bool_bin = np.logical_and(THETA>=th_bins[i], THETA<th_bins[i+1])
    pix_bin[i] = np.sum(bool_bin*this_mask)
    flux_bin[i] = np.sum(data*bool_bin*this_mask)

er_ring = np.array([np.sqrt(pix_bin[i]/pix_per_beam)*(np.sum(noise*bool_bin*this_mask)/pix_bin[i]) if not pix_bin[i]==0 else 0 \
           for i in range(num_bins)])
mean_bin = np.array([flux_bin[i]/pix_bin[i] if not pix_bin[i]<min_pix else 0 for i in range(num_bins)])
er_beam = np.array([er_ring[i]*(pix_per_beam/pix_bin[i]) if not pix_bin[i]<min_pix else 0 for i in range(num_bins)])
fig = plt.figure()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.scatter(th_bins[0:-1], mean_bin, s=4)
plt.errorbar(th_bins[0:-1], mean_bin, yerr=er_beam, fmt='none')
ax = plt.gca()
ax.set_ylim([-0.75, 0.75])
plt.xlabel(r'$\theta \rm{(rad)}$', size=16)
plt.ylabel(r'$S_{ave} \rm{(mJy/beam)}$', size=16)
#plt.title(r'residual flux; ellipse mask thickness = '+ '{:.2e}'.format(thickness) + r' rad')
#plt.savefig(base_path + 'figs/resid_flux_vs_radius_real_data_ps_ellipse_mask.pdf')
min_ind = np.where(np.min(mean_bin) == mean_bin)[0][0] 
th_mask = th_bins[min_ind]
print(th_mask)
print(pix_bin)
# Out:
# 0.0011865336088032082
# [0.000e+00 1.000e+00 3.300e+01 1.170e+02 1.440e+02 1.880e+02 2.360e+02
#  2.480e+02 2.740e+02 3.200e+02 3.570e+02 3.570e+02 4.330e+02 4.560e+02
#  4.920e+02 5.390e+02 5.530e+02 5.450e+02 6.040e+02 5.890e+02 6.270e+02
#  7.120e+02 7.230e+02 7.530e+02 8.520e+02 8.230e+02 8.310e+02 9.100e+02
#  8.630e+02 8.980e+02 9.670e+02 9.750e+02 1.039e+03 1.078e+03 9.410e+02
#  8.750e+02 8.310e+02 8.310e+02 7.730e+02 8.100e+02 8.130e+02 8.240e+02
#  8.310e+02 7.940e+02 7.930e+02 8.160e+02 7.840e+02 8.160e+02 7.980e+02
#  7.920e+02 7.500e+02 7.400e+02 7.090e+02 7.050e+02 7.730e+02 7.430e+02
#  7.680e+02 7.610e+02 7.160e+02 6.900e+02 6.890e+02 6.930e+02 6.940e+02
#  7.010e+02 7.260e+02 7.280e+02 7.660e+02 7.720e+02 7.270e+02 7.300e+02
#  7.460e+02 7.060e+02 7.450e+02 7.320e+02 7.080e+02 7.440e+02 7.180e+02
#  7.290e+02 7.590e+02 7.250e+02 7.060e+02 7.340e+02 7.130e+02 7.360e+02
#  7.420e+02 7.440e+02 7.140e+02 7.320e+02 7.390e+02 7.360e+02 7.350e+02
#  7.070e+02 6.930e+02 6.910e+02 6.430e+02 4.480e+02 3.160e+02 2.280e+02
#  1.280e+02 5.600e+01]

# %%
th_min = th_mask
th_max = np.pi
th_range_in = [th_min, th_max]
this_mask = create_mask(THETA, th_range_in, ps_ind=mask_inds)
ma_data= ma.array(data, mask=np.logical_not(this_mask))
minmin = np.min(data)
maxmax = np.max(data)
fig = plt.figure()
plt.imshow(data, vmin=minmin, vmax=maxmax)
plt.colorbar(orientation='horizontal')
#plt.savefig(base_path+'figs/real_data.pdf')
fig = plt.figure()
plt.imshow(ma_data, vmin=minmin, vmax=maxmax)
plt.colorbar(orientation='horizontal')
#plt.savefig(base_path+'figs/ps_center_masked_data.pdf')

# %%
w_init = np.array([0,  1,  4,  0.015, 3e-3])
print(w_init)
plt.imshow(ma.array(f([AX_N, AX_n], w_init), mask=np.logical_not(this_mask)))

#print initial statistics
this_chi2 = chi2(w_init, *(data, [AX_N, AX_n],  noise, this_mask))
statement1 = 'initial weights are: '
for j in range(len(w_init)):
    statement1 += 'w' + str(j) + ' = ' + str(w_init[j]) + '; '
print(statement1)
print('chi^2 = ' + str(this_chi2))

# update weights
bnds = [(-1, 1), (0, 2), (3, 5), (.01 , 0.02), (1e-3, 1e-2)]
res = minimize(chi2, w_init, args=(data, [AX_N, AX_n], noise, this_mask), bounds=bnds)

w_fin = res.x
print('w_fin: ', w_fin)
print(res.success)
print(res.message)
chi2_final = chi2(w_fin, *(data, [AX_N, AX_n], noise, this_mask))
print('final chi2: '+ str(chi2_final)) 
fig = plt.figure()
new_model = f([AX_N, AX_n], w_fin)
plt.imshow(ma.array(new_model, mask=np.logical_not(this_mask))) 
plt.colorbar(orientation='horizontal')
#plt.savefig(base_path+'figs/best_ring_model_masked.pdf')
fig = plt.figure()
plt.imshow(ma_data)
plt.colorbar(orientation='horizontal')
# Out:
# [0.0e+00 1.0e+00 4.0e+00 1.5e-02 3.0e-03]
# initial weights are: w0 = 0.0; w1 = 1.0; w2 = 4.0; w3 = 0.015; w4 = 0.003;
# chi^2 = 214702.81527259506
# w_fin:  [-1.37722367e-01  1.11281542e+00  4.20050018e+00  1.41995042e-02
#   3.70670747e-03]
# True
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# final chi2: 187455.5102155168

# %%
mode = 'load'
starting_samples = tuple((1000, 1000))
b_sim = tuple(('ring', 'noring'))
num_samples = 1000
ell_params = list(w_fin[1:])
#grab the mask thicknesses from cell 73 or 74 in compare_ringvnoring notebook
mask_thicknesses = [0, 0.0033801168648913103, 0.007859198067988, 0.009002003858080398, 0.00918183948269248]

# %%
#create masks
mask_set=[]
for thickness in mask_thicknesses:
    this_mask = create_mask(THETA, th_range_in, ps_ind=mask_inds, coords=(AX_N, AX_n), ellipse_params=[ell_params[1], ell_params[2], thickness], \
                        method='ellipse_and_azimuthally_sym')
    mask_set.append(this_mask)
mask_set = np.array(mask_set)

#prepare sets of sigmav mx and D0
frac = 2.7
beam_cut = 5
sig_type = 2
sigmav_bench = 2.2e-26
mx_start = 6
mx_stop = 500
num_mx = 20
sigmav_start = -27
sigmav_end = -23
num_sigmav = 80
num_masks = len(mask_thicknesses)

#make these be  in increasing order
D0_set_in = np.array([3e28])
mx_set_in = np.round(np.logspace(np.log10(mx_start), np.log10(mx_stop), num_mx), 1)
sigmav_ar = np.logspace(sigmav_start, sigmav_end, num_sigmav)

# %%
#extract info of runs that match criteria
run_list = mt.find_results(sig_type, mx=mx_set_in, D0=D0_set_in)
num_runs = len(run_list)
print('length of run_list: ', str(num_runs))
signal_temp_set = []
mx_set_out = []
D0_set_out = []
for run in run_list:
    print(run)
    mx_set_out.append(run['mx'])
    D0_set_out.append(run['D0'])
    this_signal_temp, _ = gen_templates(run, nu_data, omega_beam, AX_N, AX_n)
    signal_temp_set.append(this_signal_temp)
mx_set_out = np.array(mx_set_out)
D0_set_out = np.array(D0_set_out)
signal_temp_set = np.array(signal_temp_set)

#sort runs
ind = sort_runs(mx_set_out, D0_set_out)
mx_set_out = mx_set_out[ind]
D0_set_out = D0_set_out[ind]
signal_temp_set = signal_temp_set[ind]
run_list = [run_list[i] for i in ind]
# Out:
# this_path = /het/p4/mjw283/eventgen_wd/Secondary_radiation/scripts/manipulate_text.py
# length of run_list:  20
# {'file_name': '0001_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0002_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0003_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0004_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0005_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0006_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0007_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0008_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0009_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0010_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0011_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0012_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0013_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0014_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0015_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0016_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0018_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0019_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0020_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}
# {'file_name': '0021_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DA': 780.0, 'nrho': 60, 'nnu': 70, 'rho_range': [0.1, 35.0], 'nu_range': [100000.0, 1e+24]}

# %% [markdown]
# To compute $\left.\Delta\chi^2\right|_{sb}$ and $\left.\Delta\chi^2\right|_{b}$ efficiently, I plan to use numpy slicing methods. For each simulated intensity map, $\Delta\chi^2$ depends on the masked pixels, $m_\chi$, and $\langle\sigma v\rangle$. For 5 masks, 20 values of $m_\chi$, and 80 values of $\langle \sigma v\rangle$,  $\Delta\chi^2$ will have $5\times 20\times 80 = 8000$ entries. Each entry in $\Delta \chi^2$ can naively be computed by taking the differnece of $\chi^2_{sb}-\chi^2_{b}$ which each requires a sum over the non masked pixels in the image. If this sum is computed for each of the $8000$ entries separately, then the algorithm will take a long time. If terms are collected and numpy.sum is used to sum over the pixels for each entry using a numpy loop, the algorithm will be much quicker, but there may be storage problems. Before this sum is executed, the array to be summed will have a shape of $(5, 20, 80, 155, 441)$ (assuming the same number of entries as earlier) which implies that there will be $5\times 20\times 80\times 155\times 441 \simeq 5.5 \times 10^8$. Arrays take up 8 bytes per entry which means that the array will take up $4.4 \rm{Gb}$. To work around this issue I will try to break down $\Delta \chi^2$ into individual terms which each takes the form of a sum over pixels with coefficients pulled out in front of the sum. This will make it so that the array to be partially summed will not need to have all of the indices that $\Delta \chi^2$ will have but numpy loops can still be used. Starting with the background only case, where the simulated intensity in pixel $i$ is given by $R_i$, we have
# $$
# \begin{split}
# \left.\Delta \chi^2\right|_b &= \left. \chi^2_{sb}\right|_b-\left. \chi^2_{b}\right|_b \\
# &=\sum_i\frac{(R_i-f_{sb,i}^{b}(\langle\sigma v\rangle))^2}{\sigma_i^2}-\sum_i\frac{(R_i-f_{b,i}^{b})^2}{\sigma_i^2}
# \end{split}
# $$
# where $f_{sb,i}^{b}(\langle\sigma v\rangle)$ is the intensity in pixel $i$ of the signal plus background model with cross section $\langle \sigma v \rangle$ fit to the background only simulated intensity map and $f_{b,i}^{b}$is the intensity in pixel $i$ of the background-only model fit to the background only simulated intensity map. These can be written as
# $$
# \begin{split}
# &f_{sb,i}^{b} = \frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}f_{s,i}(m_\chi) + w^{b}_{sb} f_{b,i}\\
# &f_{b,i}^{b} = w^{b}_b f_{b,i}
# \end{split}
# $$
# where $f_{s,i}(m_\chi)$ is the signal intensity in pixel $i$ for a dark matter mass of $m_\chi$ for a cross section given by the benchmark cross section, $\langle \sigma v \rangle_0$ and $f_{b_i}$ is the normalized background model inensity in pixel $i$ and in our case is $1$ for all $i$. The free parameters $w^{sb}_b$ and $w^b_b$ of each model are chosen to minimize each respective $\chi^2$ are given by
# $$
# \begin{split}
# &w^{b}_b = \left[\sum_i\frac{f_{b,i}^2}{\sigma_i^2}\right]^{-1}\sum_i \frac{R_i f_{b,i}}{\sigma_i^2}\\
# &w^{b}_{sb} = \left[\sum_i\frac{f_{b,i}^2}{\sigma_i^2}\right]^{-1} \sum_i \frac{\left[R_i-\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}f_{s,i}(m_\chi)\right]f_{b,i}}{\sigma_i^2} = w^{b}_b - \left[\sum_i\frac{f_{b,i}^2}{\sigma_i^2}\right]^{-1}\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\sum_i\frac{f_{s,i}(m_\chi)f_{b,i}}{\sigma_i^2}
# \end{split}
# $$
#
# After some algebra, the equation for $\Delta \chi^2$ can be written as
# $$
# \left.\Delta\chi^2\right|_b = 2(w_b^b-w_{sb}^b)\sum_i\frac{R_i f_{b,i}}{\sigma_i^2}-2\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\sum_i\frac{R_i f_{s,i}}{\sigma_i^2}+\left(\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\right)^2\sum_i\frac{f_{s,i}^2}{\sigma_i^2}+({w_{sb}^b}^2-{w_{b}^b}^2)\sum_i\frac{f_{b,i}^2}{\sigma_i^2} +\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}w_{sb}^b\sum_i\frac{f_{b,i}f_{s,i}}{\sigma_i^2}
# $$
#
# For $\left.\Delta \chi^2\right|_{sb}$, the following replacements should be made to the first equation
#
# $$
# \begin{split}
# R_i &\rightarrow R_i + \frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}f_{s,i}(m_\chi)\\
# f_{sb}^{b} &\rightarrow f_{sb}^{sb} = \frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}f_{s,i}(m_\chi) + w^{sb}_{sb} f_{b,i}\\
# f_{b}^{b} &\rightarrow f_{b}^{sb} = w^{b}_{sb} f_{b,i}
# \end{split}
# $$
#
# where
#
# $$
# \begin{split}
# &w^{sb}_{sb} = \left[\sum_i\frac{f_{b,i}^2}{\sigma_i^2}\right]^{-1}\sum_i \frac{R_i f_{b,i}}{\sigma_i^2} = w^b_b\\
# &w^{sb}_{b} = \left[\sum_i\frac{f_{b,i}^2}{\sigma_i^2}\right]^{-1} \sum_i \frac{\left[R_i+\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}f_{s,i}(m_\chi)\right]f_{b,i}}{\sigma_i^2} = w^{sb}_{sb} + \left[\sum_i\frac{f_{b,i}^2}{\sigma_i^2}\right]^{-1}\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\sum_i\frac{f_{s,i}(m_\chi)f_{b,i}}{\sigma_i^2}
# \end{split}
# $$
#
# The result for $\left. \Delta \chi^2\right|_{sb}$ is
#
# $$
# \left. \Delta \chi^2\right|_{sb} = 2(w_b^{sb}-w_{sb}^{sb})\sum_i\frac{R_i f_{b,i}}{\sigma_i^2}-2\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\sum_i\frac{R_i f_{s,i}}{\sigma_i^2} - \left(\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\right)^2\sum_i\frac{f_{s,i}^2}{\sigma_i^2} + ({w_{sb}^{sb}}^2-{w_{b}^{sb}}^2)\sum_i\frac{f_{b,i}^2}{\sigma_i^2}+\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}w_{b}^{sb}\sum_i\frac{f_{b,i}f_{s,i}}{\sigma_i^2}
# $$

# %%
b = np.array([1, 2, 3])
print(b.itemsize)
# Out:
# 8

# %%
#initialize arrays
dchi2_sb = [np.zeros((num_masks, num_runs, num_sigmav, num_samples)) for item in b_sim]
dchi2_b = [np.zeros((num_masks, num_runs, num_sigmav, num_samples)) for item in b_sim]

# %%
dchi2_sb[0].size
# Out:
# 8000000

# %%
#compute quantities that do not need to be recalculated for each image
#isotropic background template
back_temp = np.ones((n,N))

#sums in dchi^2 that are independent of simulated intensity map
sum3 = np.einsum('ijk,ljk', mask_set, signal_temp_set**2/noise**2)
sum4 = np.sum(mask_set/(noise**2), axis=(1,2))
sum5 = np.einsum('ijk,ljk', mask_set, signal_temp_set/noise**2)

#how much should the uniform background change by if we add or subtract the signals
dw = (np.einsum('ljk,ijk', mask_set, signal_temp_set*back_temp/noise**2)/sum4).T
dw_sigmav = np.multiply.outer(dw, sigmav_ar/sigmav_bench)

#coefficients in dchi^2 that are independent of simulated intensity map. Signs on coefficeints
#are correct for dchi^2_b and some signs my need to change for dchi^2_sb
coef1 = 2*dw_sigmav #sum1
coef2 = -2*sigmav_ar/sigmav_bench #sum2
coef3 = (sigmav_ar/sigmav_bench)**2 #sum3; opposite sign for sb
coef5 = - dw_sigmav**2 #sum4; opposite sign for sb
coef7 = - dw_sigmav*sigmav_ar/sigmav_bench #sum5; opposite sign for sb

#terms in dchi^2 that are independent of simulated intensity map. Signs are correct for 
#dchi^2_b and signs need to be flipped  for dchi^2_sb where indicated
term3 = np.multiply.outer(sum3, coef3) #opposite sign for sb
term5 = (coef5.transpose((1, 2, 0))*sum4).transpose((2,0,1)) #opposite sign for sb
term7 = (coef7.transpose((2, 0, 1))*sum5).transpose((1, 2, 0)) #opposite_sign for sb

#array that is all ones with axes of dimension given by num_<item> where <item> is an item being iterated over
unit_masks = np.ones(num_masks)
unit_runs_sigmav = np.ones((num_runs, num_sigmav))

# %%
print(sum3.shape)
print(sum4.shape)
print(sum5.shape)

print(coef1.shape)
print(coef2.shape)
print(coef3.shape)
print(coef5.shape)
print(coef7.shape)

print(term3.shape)
print(term5.shape)
print(term7.shape)
# Out:
# (5, 20)
# (5,)
# (5, 20)
# (5, 20, 80)
# (80,)
# (80,)
# (5, 20, 80)
# (5, 20, 80)
# (5, 20, 80)
# (5, 20, 80)
# (5, 20, 80)

# %%
for i in range(num_samples):
    print('starting to generate sample number ' + str(i))
    #generate fake data residuals                                                                                                                                                       
    file_name_base = base_path + 'fake_resid_new/sigma_rms_'+ str(sigma_rms[0]) + '_' + \
                     str(sigma_rms[-1]) + '_spacing_' + '{:.2e}'.format(dlt_N/frac) + '_samplenum_'
    file_name=file_name_base+str(i+starting_samples[0]) + '.npy'
    if mode == 'save' or mode == 'none':
        data_resid, _, _ = gen_fake_data(beam_cut, frac, sigma_rms_vals, sigma_BW, N, n, dlt_N, dlt_n)
        if mode == 'save':
            np.save(file_name, data_resid)
        print('sample number '+ str(starting_samples[0]+i) + ' generated')
    elif mode == 'load':
        data_resid = np.load(file_name)
    else:
        print('value mode is not recognized')

    #add residuals to best fit ring model                                                                                                                                               
    w_sim = [0] + ell_params
    fake_bmaps = [data_resid  + f([AX_N, AX_n], w_sim) if b=='ring' else data_resid for b in b_sim]
    this_wsb_sb = [np.sum(mask_set*bmap*back_temp/noise**2, axis=(1,2))/sum4 for bmap in fake_bmaps]
    #this_wb_b = this_wsb_sb
    #this_chi_b_b = [np.sum(mask_set*(np.multiply.outer(unit_masks, bmap)-np.multiply.outer(w, back_temp))**2/noise**2, axis=(1,2)) \
    #               for bmap in fake_bmaps]
    #notation: wi_j is the background intensity when fitting model i to data simulated from j
    #this_wsb_sb_repeat = [np.multiply.outer(w, unit_runs_sigmav) for w in this_wsb_sb]
    #this_wb_sb = [twr + dw_sigmav for twr in this_wsb_sb_repeat] # shape=(num_masks, num_runs, num_sigmav)
    #this_wsb_b = [twr - dw_sigmav for twr in this_wsb_sb_repeat] # shape=(num_masks, num_runs, num_sigmav)
    sum1 = [np.sum(mask_set*bmap/noise**2, axis=(1,2)) for bmap in fake_bmaps]
    sum2 = [np.einsum('ijk,ljk', mask_set*bmap/(noise**2) , signal_temp_set) for bmap in fake_bmaps]
    
    coef4 = [2*(dw_sigmav.transpose((1, 2, 0))*w).transpose((2,0,1)) for w in this_wsb_sb] #sum4
    #coef6 = [np.multiply.outer(w, sigmav_ar/sigmav_bench) for w in this_wsb_sb] #sum5 (more effficient 
    #to wait to multiply until combining with sum5)
    
    term1 = [(coef1.transpose((1,2,0))*s).transpose((2,0,1)) for s in sum1]
    term2 = [np.multiply.outer(s, coef2) for s in sum2]
    term4 = [(c.transpose((1, 2, 0))*sum4).transpose((2,0,1)) for c in coef4]
    term6 = [np.multiply.outer(((sum5.T*w).T), sigmav_ar/sigmav_bench) for w in this_wsb_sb]
    
    this_dchi2_b = [t1+t2+term3+t4+term5+t6+term7 for t1,t2,t4,t6 in zip(term1, term2, term4, term6)]
    this_dchi2_sb = [t1+t2-term3+t4-term5+t6-term7 for t1,t2,t4,t6 in zip(term1, term2, term4, term6)]
    for ind in range(len(b_sim)):
        dchi2_b[ind][:, : , :, i] = this_dchi2_b[ind]
        dchi2_sb[ind][:, : , :, i] = this_dchi2_sb[ind]
# Out:
# starting to generate sample number 0
# starting to generate sample number 1
# starting to generate sample number 2
# starting to generate sample number 3
# starting to generate sample number 4
# starting to generate sample number 5
# starting to generate sample number 6
# starting to generate sample number 7
# starting to generate sample number 8
# starting to generate sample number 9
# starting to generate sample number 10
# starting to generate sample number 11
# starting to generate sample number 12
# starting to generate sample number 13
# starting to generate sample number 14
# starting to generate sample number 15
# starting to generate sample number 16
# starting to generate sample number 17
# starting to generate sample number 18
# starting to generate sample number 19
# starting to generate sample number 20
# starting to generate sample number 21
# starting to generate sample number 22
# starting to generate sample number 23
# starting to generate sample number 24
# starting to generate sample number 25
# starting to generate sample number 26
# starting to generate sample number 27
# starting to generate sample number 28
# starting to generate sample number 29
# starting to generate sample number 30
# starting to generate sample number 31
# starting to generate sample number 32
# starting to generate sample number 33
# starting to generate sample number 34
# starting to generate sample number 35
# starting to generate sample number 36
# starting to generate sample number 37
# starting to generate sample number 38
# starting to generate sample number 39
# starting to generate sample number 40
# starting to generate sample number 41
# starting to generate sample number 42
# starting to generate sample number 43
# starting to generate sample number 44
# starting to generate sample number 45
# starting to generate sample number 46
# starting to generate sample number 47
# starting to generate sample number 48
# starting to generate sample number 49
# starting to generate sample number 50
# starting to generate sample number 51
# starting to generate sample number 52
# starting to generate sample number 53
# starting to generate sample number 54
# starting to generate sample number 55
# starting to generate sample number 56
# starting to generate sample number 57
# starting to generate sample number 58
# starting to generate sample number 59
# starting to generate sample number 60
# starting to generate sample number 61
# starting to generate sample number 62
# starting to generate sample number 63
# starting to generate sample number 64
# starting to generate sample number 65
# starting to generate sample number 66
# starting to generate sample number 67
# starting to generate sample number 68
# starting to generate sample number 69
# starting to generate sample number 70
# starting to generate sample number 71
# starting to generate sample number 72
# starting to generate sample number 73
# starting to generate sample number 74
# starting to generate sample number 75
# starting to generate sample number 76
# starting to generate sample number 77
# starting to generate sample number 78
# starting to generate sample number 79
# starting to generate sample number 80
# starting to generate sample number 81
# starting to generate sample number 82
# starting to generate sample number 83
# starting to generate sample number 84
# starting to generate sample number 85
# starting to generate sample number 86
# starting to generate sample number 87
# starting to generate sample number 88
# starting to generate sample number 89
# starting to generate sample number 90
# starting to generate sample number 91
# starting to generate sample number 92
# starting to generate sample number 93
# starting to generate sample number 94
# starting to generate sample number 95
# starting to generate sample number 96
# starting to generate sample number 97
# starting to generate sample number 98
# starting to generate sample number 99
# starting to generate sample number 100
# starting to generate sample number 101
# starting to generate sample number 102
# starting to generate sample number 103
# starting to generate sample number 104
# starting to generate sample number 105
# starting to generate sample number 106
# starting to generate sample number 107
# starting to generate sample number 108
# starting to generate sample number 109
# starting to generate sample number 110
# starting to generate sample number 111
# starting to generate sample number 112
# starting to generate sample number 113
# starting to generate sample number 114
# starting to generate sample number 115
# starting to generate sample number 116
# starting to generate sample number 117
# starting to generate sample number 118
# starting to generate sample number 119
# starting to generate sample number 120
# starting to generate sample number 121
# starting to generate sample number 122
# starting to generate sample number 123
# starting to generate sample number 124
# starting to generate sample number 125
# starting to generate sample number 126
# starting to generate sample number 127
# starting to generate sample number 128
# starting to generate sample number 129
# starting to generate sample number 130
# starting to generate sample number 131
# starting to generate sample number 132
# starting to generate sample number 133
# starting to generate sample number 134
# starting to generate sample number 135
# starting to generate sample number 136
# starting to generate sample number 137
# starting to generate sample number 138
# starting to generate sample number 139
# starting to generate sample number 140
# starting to generate sample number 141
# starting to generate sample number 142
# starting to generate sample number 143
# starting to generate sample number 144
# starting to generate sample number 145
# starting to generate sample number 146
# starting to generate sample number 147
# starting to generate sample number 148
# starting to generate sample number 149
# starting to generate sample number 150
# starting to generate sample number 151
# starting to generate sample number 152
# starting to generate sample number 153
# starting to generate sample number 154
# starting to generate sample number 155
# starting to generate sample number 156
# starting to generate sample number 157
# starting to generate sample number 158
# starting to generate sample number 159
# starting to generate sample number 160
# starting to generate sample number 161
# starting to generate sample number 162
# starting to generate sample number 163
# starting to generate sample number 164
# starting to generate sample number 165
# starting to generate sample number 166
# starting to generate sample number 167
# starting to generate sample number 168
# starting to generate sample number 169
# starting to generate sample number 170
# starting to generate sample number 171
# starting to generate sample number 172
# starting to generate sample number 173
# starting to generate sample number 174
# starting to generate sample number 175
# starting to generate sample number 176
# starting to generate sample number 177
# starting to generate sample number 178
# starting to generate sample number 179
# starting to generate sample number 180
# starting to generate sample number 181
# starting to generate sample number 182
# starting to generate sample number 183
# starting to generate sample number 184
# starting to generate sample number 185
# starting to generate sample number 186
# starting to generate sample number 187
# starting to generate sample number 188
# starting to generate sample number 189
# starting to generate sample number 190
# starting to generate sample number 191
# starting to generate sample number 192
# starting to generate sample number 193
# starting to generate sample number 194
# starting to generate sample number 195
# starting to generate sample number 196
# starting to generate sample number 197
# starting to generate sample number 198
# starting to generate sample number 199
# starting to generate sample number 200
# starting to generate sample number 201
# starting to generate sample number 202
# starting to generate sample number 203
# starting to generate sample number 204
# starting to generate sample number 205
# starting to generate sample number 206
# starting to generate sample number 207
# starting to generate sample number 208
# starting to generate sample number 209
# starting to generate sample number 210
# starting to generate sample number 211
# starting to generate sample number 212
# starting to generate sample number 213
# starting to generate sample number 214
# starting to generate sample number 215
# starting to generate sample number 216
# starting to generate sample number 217
# starting to generate sample number 218
# starting to generate sample number 219
# starting to generate sample number 220
# starting to generate sample number 221
# starting to generate sample number 222
# starting to generate sample number 223
# starting to generate sample number 224
# starting to generate sample number 225
# starting to generate sample number 226
# starting to generate sample number 227
# starting to generate sample number 228
# starting to generate sample number 229
# starting to generate sample number 230
# starting to generate sample number 231
# starting to generate sample number 232
# starting to generate sample number 233
# starting to generate sample number 234
# starting to generate sample number 235
# starting to generate sample number 236
# starting to generate sample number 237
# starting to generate sample number 238
# starting to generate sample number 239
# starting to generate sample number 240
# starting to generate sample number 241
# starting to generate sample number 242
# starting to generate sample number 243
# starting to generate sample number 244
# starting to generate sample number 245
# starting to generate sample number 246
# starting to generate sample number 247
# starting to generate sample number 248
# starting to generate sample number 249
# starting to generate sample number 250
# starting to generate sample number 251
# starting to generate sample number 252
# starting to generate sample number 253
# starting to generate sample number 254
# starting to generate sample number 255
# starting to generate sample number 256
# starting to generate sample number 257
# starting to generate sample number 258
# starting to generate sample number 259
# starting to generate sample number 260
# starting to generate sample number 261
# starting to generate sample number 262
# starting to generate sample number 263
# starting to generate sample number 264
# starting to generate sample number 265
# starting to generate sample number 266
# starting to generate sample number 267
# starting to generate sample number 268
# starting to generate sample number 269
# starting to generate sample number 270
# starting to generate sample number 271
# starting to generate sample number 272
# starting to generate sample number 273
# starting to generate sample number 274
# starting to generate sample number 275
# starting to generate sample number 276
# starting to generate sample number 277
# starting to generate sample number 278
# starting to generate sample number 279
# starting to generate sample number 280
# starting to generate sample number 281
# starting to generate sample number 282
# starting to generate sample number 283
# starting to generate sample number 284
# starting to generate sample number 285
# starting to generate sample number 286
# starting to generate sample number 287
# starting to generate sample number 288
# starting to generate sample number 289
# starting to generate sample number 290
# starting to generate sample number 291
# starting to generate sample number 292
# starting to generate sample number 293
# starting to generate sample number 294
# starting to generate sample number 295
# starting to generate sample number 296
# starting to generate sample number 297
# starting to generate sample number 298
# starting to generate sample number 299
# starting to generate sample number 300
# starting to generate sample number 301
# starting to generate sample number 302
# starting to generate sample number 303
# starting to generate sample number 304
# starting to generate sample number 305
# starting to generate sample number 306
# starting to generate sample number 307
# starting to generate sample number 308
# starting to generate sample number 309
# starting to generate sample number 310
# starting to generate sample number 311
# starting to generate sample number 312
# starting to generate sample number 313
# starting to generate sample number 314
# starting to generate sample number 315
# starting to generate sample number 316
# starting to generate sample number 317
# starting to generate sample number 318
# starting to generate sample number 319
# starting to generate sample number 320
# starting to generate sample number 321
# starting to generate sample number 322
# starting to generate sample number 323
# starting to generate sample number 324
# starting to generate sample number 325
# starting to generate sample number 326
# starting to generate sample number 327
# starting to generate sample number 328
# starting to generate sample number 329
# starting to generate sample number 330
# starting to generate sample number 331
# starting to generate sample number 332
# starting to generate sample number 333
# starting to generate sample number 334
# starting to generate sample number 335
# starting to generate sample number 336
# starting to generate sample number 337
# starting to generate sample number 338
# starting to generate sample number 339
# starting to generate sample number 340
# starting to generate sample number 341
# starting to generate sample number 342
# starting to generate sample number 343
# starting to generate sample number 344
# starting to generate sample number 345
# starting to generate sample number 346
# starting to generate sample number 347
# starting to generate sample number 348
# starting to generate sample number 349
# starting to generate sample number 350
# starting to generate sample number 351
# starting to generate sample number 352
# starting to generate sample number 353
# starting to generate sample number 354
# starting to generate sample number 355
# starting to generate sample number 356
# starting to generate sample number 357
# starting to generate sample number 358
# starting to generate sample number 359
# starting to generate sample number 360
# starting to generate sample number 361
# starting to generate sample number 362
# starting to generate sample number 363
# starting to generate sample number 364
# starting to generate sample number 365
# starting to generate sample number 366
# starting to generate sample number 367
# starting to generate sample number 368
# starting to generate sample number 369
# starting to generate sample number 370
# starting to generate sample number 371
# starting to generate sample number 372
# starting to generate sample number 373
# starting to generate sample number 374
# starting to generate sample number 375
# starting to generate sample number 376
# starting to generate sample number 377
# starting to generate sample number 378
# starting to generate sample number 379
# starting to generate sample number 380
# starting to generate sample number 381
# starting to generate sample number 382
# starting to generate sample number 383
# starting to generate sample number 384
# starting to generate sample number 385
# starting to generate sample number 386
# starting to generate sample number 387
# starting to generate sample number 388
# starting to generate sample number 389
# starting to generate sample number 390
# starting to generate sample number 391
# starting to generate sample number 392
# starting to generate sample number 393
# starting to generate sample number 394
# starting to generate sample number 395
# starting to generate sample number 396
# starting to generate sample number 397
# starting to generate sample number 398
# starting to generate sample number 399
# starting to generate sample number 400
# starting to generate sample number 401
# starting to generate sample number 402
# starting to generate sample number 403
# starting to generate sample number 404
# starting to generate sample number 405
# starting to generate sample number 406
# starting to generate sample number 407
# starting to generate sample number 408
# starting to generate sample number 409
# starting to generate sample number 410
# starting to generate sample number 411
# starting to generate sample number 412
# starting to generate sample number 413
# starting to generate sample number 414
# starting to generate sample number 415
# starting to generate sample number 416
# starting to generate sample number 417
# starting to generate sample number 418
# starting to generate sample number 419
# starting to generate sample number 420
# starting to generate sample number 421
# starting to generate sample number 422
# starting to generate sample number 423
# starting to generate sample number 424
# starting to generate sample number 425
# starting to generate sample number 426
# starting to generate sample number 427
# starting to generate sample number 428
# starting to generate sample number 429
# starting to generate sample number 430
# starting to generate sample number 431
# starting to generate sample number 432
# starting to generate sample number 433
# starting to generate sample number 434
# starting to generate sample number 435
# starting to generate sample number 436
# starting to generate sample number 437
# starting to generate sample number 438
# starting to generate sample number 439
# starting to generate sample number 440
# starting to generate sample number 441
# starting to generate sample number 442
# starting to generate sample number 443
# starting to generate sample number 444
# starting to generate sample number 445
# starting to generate sample number 446
# starting to generate sample number 447
# starting to generate sample number 448
# starting to generate sample number 449
# starting to generate sample number 450
# starting to generate sample number 451
# starting to generate sample number 452
# starting to generate sample number 453
# starting to generate sample number 454
# starting to generate sample number 455
# starting to generate sample number 456
# starting to generate sample number 457
# starting to generate sample number 458
# starting to generate sample number 459
# starting to generate sample number 460
# starting to generate sample number 461
# starting to generate sample number 462
# starting to generate sample number 463
# starting to generate sample number 464
# starting to generate sample number 465
# starting to generate sample number 466
# starting to generate sample number 467
# starting to generate sample number 468
# starting to generate sample number 469
# starting to generate sample number 470
# starting to generate sample number 471
# starting to generate sample number 472
# starting to generate sample number 473
# starting to generate sample number 474
# starting to generate sample number 475
# starting to generate sample number 476
# starting to generate sample number 477
# starting to generate sample number 478
# starting to generate sample number 479
# starting to generate sample number 480
# starting to generate sample number 481
# starting to generate sample number 482
# starting to generate sample number 483
# starting to generate sample number 484
# starting to generate sample number 485
# starting to generate sample number 486
# starting to generate sample number 487
# starting to generate sample number 488
# starting to generate sample number 489
# starting to generate sample number 490
# starting to generate sample number 491
# starting to generate sample number 492
# starting to generate sample number 493
# starting to generate sample number 494
# starting to generate sample number 495
# starting to generate sample number 496
# starting to generate sample number 497
# starting to generate sample number 498
# starting to generate sample number 499
# starting to generate sample number 500
# starting to generate sample number 501
# starting to generate sample number 502
# starting to generate sample number 503
# starting to generate sample number 504
# starting to generate sample number 505
# starting to generate sample number 506
# starting to generate sample number 507
# starting to generate sample number 508
# starting to generate sample number 509
# starting to generate sample number 510
# starting to generate sample number 511
# starting to generate sample number 512
# starting to generate sample number 513
# starting to generate sample number 514
# starting to generate sample number 515
# starting to generate sample number 516
# starting to generate sample number 517
# starting to generate sample number 518
# starting to generate sample number 519
# starting to generate sample number 520
# starting to generate sample number 521
# starting to generate sample number 522
# starting to generate sample number 523
# starting to generate sample number 524
# starting to generate sample number 525
# starting to generate sample number 526
# starting to generate sample number 527
# starting to generate sample number 528
# starting to generate sample number 529
# starting to generate sample number 530
# starting to generate sample number 531
# starting to generate sample number 532
# starting to generate sample number 533
# starting to generate sample number 534
# starting to generate sample number 535
# starting to generate sample number 536
# starting to generate sample number 537
# starting to generate sample number 538
# starting to generate sample number 539
# starting to generate sample number 540
# starting to generate sample number 541
# starting to generate sample number 542
# starting to generate sample number 543
# starting to generate sample number 544
# starting to generate sample number 545
# starting to generate sample number 546
# starting to generate sample number 547
# starting to generate sample number 548
# starting to generate sample number 549
# starting to generate sample number 550
# starting to generate sample number 551
# starting to generate sample number 552
# starting to generate sample number 553
# starting to generate sample number 554
# starting to generate sample number 555
# starting to generate sample number 556
# starting to generate sample number 557
# starting to generate sample number 558
# starting to generate sample number 559
# starting to generate sample number 560
# starting to generate sample number 561
# starting to generate sample number 562
# starting to generate sample number 563
# starting to generate sample number 564
# starting to generate sample number 565
# starting to generate sample number 566
# starting to generate sample number 567
# starting to generate sample number 568
# starting to generate sample number 569
# starting to generate sample number 570
# starting to generate sample number 571
# starting to generate sample number 572
# starting to generate sample number 573
# starting to generate sample number 574
# starting to generate sample number 575
# starting to generate sample number 576
# starting to generate sample number 577
# starting to generate sample number 578
# starting to generate sample number 579
# starting to generate sample number 580
# starting to generate sample number 581
# starting to generate sample number 582
# starting to generate sample number 583
# starting to generate sample number 584
# starting to generate sample number 585
# starting to generate sample number 586
# starting to generate sample number 587
# starting to generate sample number 588
# starting to generate sample number 589
# starting to generate sample number 590
# starting to generate sample number 591
# starting to generate sample number 592
# starting to generate sample number 593
# starting to generate sample number 594
# starting to generate sample number 595
# starting to generate sample number 596
# starting to generate sample number 597
# starting to generate sample number 598
# starting to generate sample number 599
# starting to generate sample number 600
# starting to generate sample number 601
# starting to generate sample number 602
# starting to generate sample number 603
# starting to generate sample number 604
# starting to generate sample number 605
# starting to generate sample number 606
# starting to generate sample number 607
# starting to generate sample number 608
# starting to generate sample number 609
# starting to generate sample number 610
# starting to generate sample number 611
# starting to generate sample number 612
# starting to generate sample number 613
# starting to generate sample number 614
# starting to generate sample number 615
# starting to generate sample number 616
# starting to generate sample number 617
# starting to generate sample number 618
# starting to generate sample number 619
# starting to generate sample number 620
# starting to generate sample number 621
# starting to generate sample number 622
# starting to generate sample number 623
# starting to generate sample number 624
# starting to generate sample number 625
# starting to generate sample number 626
# starting to generate sample number 627
# starting to generate sample number 628
# starting to generate sample number 629
# starting to generate sample number 630
# starting to generate sample number 631
# starting to generate sample number 632
# starting to generate sample number 633
# starting to generate sample number 634
# starting to generate sample number 635
# starting to generate sample number 636
# starting to generate sample number 637
# starting to generate sample number 638
# starting to generate sample number 639
# starting to generate sample number 640
# starting to generate sample number 641
# starting to generate sample number 642
# starting to generate sample number 643
# starting to generate sample number 644
# starting to generate sample number 645
# starting to generate sample number 646
# starting to generate sample number 647
# starting to generate sample number 648
# starting to generate sample number 649
# starting to generate sample number 650
# starting to generate sample number 651
# starting to generate sample number 652
# starting to generate sample number 653
# starting to generate sample number 654
# starting to generate sample number 655
# starting to generate sample number 656
# starting to generate sample number 657
# starting to generate sample number 658
# starting to generate sample number 659
# starting to generate sample number 660
# starting to generate sample number 661
# starting to generate sample number 662
# starting to generate sample number 663
# starting to generate sample number 664
# starting to generate sample number 665
# starting to generate sample number 666
# starting to generate sample number 667
# starting to generate sample number 668
# starting to generate sample number 669
# starting to generate sample number 670
# starting to generate sample number 671
# starting to generate sample number 672
# starting to generate sample number 673
# starting to generate sample number 674
# starting to generate sample number 675
# starting to generate sample number 676
# starting to generate sample number 677
# starting to generate sample number 678
# starting to generate sample number 679
# starting to generate sample number 680
# starting to generate sample number 681
# starting to generate sample number 682
# starting to generate sample number 683
# starting to generate sample number 684
# starting to generate sample number 685
# starting to generate sample number 686
# starting to generate sample number 687
# starting to generate sample number 688
# starting to generate sample number 689
# starting to generate sample number 690
# starting to generate sample number 691
# starting to generate sample number 692
# starting to generate sample number 693
# starting to generate sample number 694
# starting to generate sample number 695
# starting to generate sample number 696
# starting to generate sample number 697
# starting to generate sample number 698
# starting to generate sample number 699
# starting to generate sample number 700
# starting to generate sample number 701
# starting to generate sample number 702
# starting to generate sample number 703
# starting to generate sample number 704
# starting to generate sample number 705
# starting to generate sample number 706
# starting to generate sample number 707
# starting to generate sample number 708
# starting to generate sample number 709
# starting to generate sample number 710
# starting to generate sample number 711
# starting to generate sample number 712
# starting to generate sample number 713
# starting to generate sample number 714
# starting to generate sample number 715
# starting to generate sample number 716
# starting to generate sample number 717
# starting to generate sample number 718
# starting to generate sample number 719
# starting to generate sample number 720
# starting to generate sample number 721
# starting to generate sample number 722
# starting to generate sample number 723
# starting to generate sample number 724
# starting to generate sample number 725
# starting to generate sample number 726
# starting to generate sample number 727
# starting to generate sample number 728
# starting to generate sample number 729
# starting to generate sample number 730
# starting to generate sample number 731
# starting to generate sample number 732
# starting to generate sample number 733
# starting to generate sample number 734
# starting to generate sample number 735
# starting to generate sample number 736
# starting to generate sample number 737
# starting to generate sample number 738
# starting to generate sample number 739
# starting to generate sample number 740
# starting to generate sample number 741
# starting to generate sample number 742
# starting to generate sample number 743
# starting to generate sample number 744
# starting to generate sample number 745
# starting to generate sample number 746
# starting to generate sample number 747
# starting to generate sample number 748
# starting to generate sample number 749
# starting to generate sample number 750
# starting to generate sample number 751
# starting to generate sample number 752
# starting to generate sample number 753
# starting to generate sample number 754
# starting to generate sample number 755
# starting to generate sample number 756
# starting to generate sample number 757
# starting to generate sample number 758
# starting to generate sample number 759
# starting to generate sample number 760
# starting to generate sample number 761
# starting to generate sample number 762
# starting to generate sample number 763
# starting to generate sample number 764
# starting to generate sample number 765
# starting to generate sample number 766
# starting to generate sample number 767
# starting to generate sample number 768
# starting to generate sample number 769
# starting to generate sample number 770
# starting to generate sample number 771
# starting to generate sample number 772
# starting to generate sample number 773
# starting to generate sample number 774
# starting to generate sample number 775
# starting to generate sample number 776
# starting to generate sample number 777
# starting to generate sample number 778
# starting to generate sample number 779
# starting to generate sample number 780
# starting to generate sample number 781
# starting to generate sample number 782
# starting to generate sample number 783
# starting to generate sample number 784
# starting to generate sample number 785
# starting to generate sample number 786
# starting to generate sample number 787
# starting to generate sample number 788
# starting to generate sample number 789
# starting to generate sample number 790
# starting to generate sample number 791
# starting to generate sample number 792
# starting to generate sample number 793
# starting to generate sample number 794
# starting to generate sample number 795
# starting to generate sample number 796
# starting to generate sample number 797
# starting to generate sample number 798
# starting to generate sample number 799
# starting to generate sample number 800
# starting to generate sample number 801
# starting to generate sample number 802
# starting to generate sample number 803
# starting to generate sample number 804
# starting to generate sample number 805
# starting to generate sample number 806
# starting to generate sample number 807
# starting to generate sample number 808
# starting to generate sample number 809
# starting to generate sample number 810
# starting to generate sample number 811
# starting to generate sample number 812
# starting to generate sample number 813
# starting to generate sample number 814
# starting to generate sample number 815
# starting to generate sample number 816
# starting to generate sample number 817
# starting to generate sample number 818
# starting to generate sample number 819
# starting to generate sample number 820
# starting to generate sample number 821
# starting to generate sample number 822
# starting to generate sample number 823
# starting to generate sample number 824
# starting to generate sample number 825
# starting to generate sample number 826
# starting to generate sample number 827
# starting to generate sample number 828
# starting to generate sample number 829
# starting to generate sample number 830
# starting to generate sample number 831
# starting to generate sample number 832
# starting to generate sample number 833
# starting to generate sample number 834
# starting to generate sample number 835
# starting to generate sample number 836
# starting to generate sample number 837
# starting to generate sample number 838
# starting to generate sample number 839
# starting to generate sample number 840
# starting to generate sample number 841
# starting to generate sample number 842
# starting to generate sample number 843
# starting to generate sample number 844
# starting to generate sample number 845
# starting to generate sample number 846
# starting to generate sample number 847
# starting to generate sample number 848
# starting to generate sample number 849
# starting to generate sample number 850
# starting to generate sample number 851
# starting to generate sample number 852
# starting to generate sample number 853
# starting to generate sample number 854
# starting to generate sample number 855
# starting to generate sample number 856
# starting to generate sample number 857
# starting to generate sample number 858
# starting to generate sample number 859
# starting to generate sample number 860
# starting to generate sample number 861
# starting to generate sample number 862
# starting to generate sample number 863
# starting to generate sample number 864
# starting to generate sample number 865
# starting to generate sample number 866
# starting to generate sample number 867
# starting to generate sample number 868
# starting to generate sample number 869
# starting to generate sample number 870
# starting to generate sample number 871
# starting to generate sample number 872
# starting to generate sample number 873
# starting to generate sample number 874
# starting to generate sample number 875
# starting to generate sample number 876
# starting to generate sample number 877
# starting to generate sample number 878
# starting to generate sample number 879
# starting to generate sample number 880
# starting to generate sample number 881
# starting to generate sample number 882
# starting to generate sample number 883
# starting to generate sample number 884
# starting to generate sample number 885
# starting to generate sample number 886
# starting to generate sample number 887
# starting to generate sample number 888
# starting to generate sample number 889
# starting to generate sample number 890
# starting to generate sample number 891
# starting to generate sample number 892
# starting to generate sample number 893
# starting to generate sample number 894
# starting to generate sample number 895
# starting to generate sample number 896
# starting to generate sample number 897
# starting to generate sample number 898
# starting to generate sample number 899
# starting to generate sample number 900
# starting to generate sample number 901
# starting to generate sample number 902
# starting to generate sample number 903
# starting to generate sample number 904
# starting to generate sample number 905
# starting to generate sample number 906
# starting to generate sample number 907
# starting to generate sample number 908
# starting to generate sample number 909
# starting to generate sample number 910
# starting to generate sample number 911
# starting to generate sample number 912
# starting to generate sample number 913
# starting to generate sample number 914
# starting to generate sample number 915
# starting to generate sample number 916
# starting to generate sample number 917
# starting to generate sample number 918
# starting to generate sample number 919
# starting to generate sample number 920
# starting to generate sample number 921
# starting to generate sample number 922
# starting to generate sample number 923
# starting to generate sample number 924
# starting to generate sample number 925
# starting to generate sample number 926
# starting to generate sample number 927
# starting to generate sample number 928
# starting to generate sample number 929
# starting to generate sample number 930
# starting to generate sample number 931
# starting to generate sample number 932
# starting to generate sample number 933
# starting to generate sample number 934
# starting to generate sample number 935
# starting to generate sample number 936
# starting to generate sample number 937
# starting to generate sample number 938
# starting to generate sample number 939
# starting to generate sample number 940
# starting to generate sample number 941
# starting to generate sample number 942
# starting to generate sample number 943
# starting to generate sample number 944
# starting to generate sample number 945
# starting to generate sample number 946
# starting to generate sample number 947
# starting to generate sample number 948
# starting to generate sample number 949
# starting to generate sample number 950
# starting to generate sample number 951
# starting to generate sample number 952
# starting to generate sample number 953
# starting to generate sample number 954
# starting to generate sample number 955
# starting to generate sample number 956
# starting to generate sample number 957
# starting to generate sample number 958
# starting to generate sample number 959
# starting to generate sample number 960
# starting to generate sample number 961
# starting to generate sample number 962
# starting to generate sample number 963
# starting to generate sample number 964
# starting to generate sample number 965
# starting to generate sample number 966
# starting to generate sample number 967
# starting to generate sample number 968
# starting to generate sample number 969
# starting to generate sample number 970
# starting to generate sample number 971
# starting to generate sample number 972
# starting to generate sample number 973
# starting to generate sample number 974
# starting to generate sample number 975
# starting to generate sample number 976
# starting to generate sample number 977
# starting to generate sample number 978
# starting to generate sample number 979
# starting to generate sample number 980
# starting to generate sample number 981
# starting to generate sample number 982
# starting to generate sample number 983
# starting to generate sample number 984
# starting to generate sample number 985
# starting to generate sample number 986
# starting to generate sample number 987
# starting to generate sample number 988
# starting to generate sample number 989
# starting to generate sample number 990
# starting to generate sample number 991
# starting to generate sample number 992
# starting to generate sample number 993
# starting to generate sample number 994
# starting to generate sample number 995
# starting to generate sample number 996
# starting to generate sample number 997
# starting to generate sample number 998
# starting to generate sample number 999

# %% [markdown]
# The relevant expressions to the cell above are
# $$
# \left.\Delta\chi^2\right|_b = 2(w_b^b-w_{sb}^b)\sum_i\frac{R_i f_{b,i}}{\sigma_i^2}-2\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\sum_i\frac{R_i f_{s,i}}{\sigma_i^2}+\left(\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\right)^2\sum_i\frac{f_{s,i}^2}{\sigma_i^2}+({w_{sb}^b}^2-{w_{b}^b}^2)\sum_i\frac{f_{b,i}^2}{\sigma_i^2} +\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}w_{sb}^b\sum_i\frac{f_{b,i}f_{s,i}}{\sigma_i^2}
# $$
#
# $$
# \left. \Delta \chi^2\right|_{sb} = 2(w_b^{sb}-w_{sb}^{sb})\sum_i\frac{R_i f_{b,i}}{\sigma_i^2}-2\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\sum_i\frac{R_i f_{s,i}}{\sigma_i^2} - \left(\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}\right)^2\sum_i\frac{f_{s,i}^2}{\sigma_i^2} + ({w_{sb}^{sb}}^2-{w_{b}^{sb}}^2)\sum_i\frac{f_{b,i}^2}{\sigma_i^2}+\frac{\langle\sigma v\rangle}{\langle\sigma v\rangle_0}w_{b}^{sb}\sum_i\frac{f_{b,i}f_{s,i}}{\sigma_i^2}
# $$

# %%
#plt.hist(dchi2_b[0][4, 10, 20], label=b_sim[0]+' b', alpha=.5)
#plt.hist(dchi2_sb[0][4, 10, 20], label=b_sim[0]+' sb', alpha=.5)
#plt.legend()

dchi2_b_mean = [np.mean(d, axis=-1) for d in dchi2_b]
dchi2_b_std = [np.std(d, axis=-1) for d in dchi2_b]
dchi2_sb_mean = [np.mean(d, axis=-1) for d in dchi2_sb]
dchi2_sb_std = [np.std(d, axis=-1) for d in dchi2_sb]
#dchi2_b_srt = [np.sort(d) for d in dchi2_b]
#dchi2_sb_srt = [np.sort(d) for d in dchi2_sb]

m=0
mchi = 10
sv = 20
this_dchi = dchi2_b[0][m, mchi, sv]
this_dchi_mean = dchi2_b_mean[0][m, mchi, sv]
this_dchi_std = dchi2_b_std[0][m, mchi, sv]
this_dchi_srt = dchi2_b_srt[0][m, mchi, sv]
p_ar = np.arange(1, len(this_dchi_srt)+1)/len(this_dchi_srt)
mini = np.min(this_dchi)
maxi = np.max(this_dchi)
dchi_ar = np.linspace(mini, maxi, 1000)
z_range = 5
num_z = 10000
z = np.linspace(-z_range, z_range, num_z)
p_unit = norm.cdf(z)
fig = plt.figure()
plt.plot(dchi_ar[:300], p[:300], label='norm cdf')
plt.plot(this_dchi_srt[:100], p_ar[:100], label='actual')
plt.legend()

# %%
dchi2_b_mean = [np.mean(d, axis=-1) for d in dchi2_b]
dchi2_b_std = [np.std(d, axis=-1) for d in dchi2_b]
dchi2_sb_mean = [np.mean(d, axis=-1) for d in dchi2_sb]
dchi2_sb_std = [np.std(d, axis=-1) for d in dchi2_sb]
dchi_arrs= [np.linspace(dchi2_b_mean[i][j,k,l]-4*dchi2_b_stddchi2_b_mean[i][j,k,l], dmeandchi2_b_mean[i][j,k,l]+4*dstddchi2_b_mean[i][j,k,l], 5000)
p = [norm.cdf(, loc=dmean, scale=dstd) for dmean,dstd in zip(dmean)]
# Out:
# (10, 10, 3)
