# %%
import numpy as np
from astropy.io import fits
import os
import matplotlib.pyplot as plt
import re
from scipy import interpolate
import manipulate_text as mt
import copy
import itertools
import argparse
import numpy.ma as ma
from scipy.optimize import minimize, fsolve
import time
from scipy.stats import norm
import matplotlib.mlab as mlab

# %%
#define relevant paths and names
#script_path = os.path.realpath(__file__) if a .py is run
script_path = os.getcwd()
base_path =  script_path.split('scripts')[0]
fits_path = base_path.split('Secondary_radiation')[0] + 'synchrotron_data/'
fits_name = 'm31cm3nthnew.ss.90sec.fits'
fig_path = base_path + 'figs/'

# %%
def get_data_and_info(fits_path, fits_name):
    #extract data and information about data
    hdul = fits.open(fits_path+fits_name)
    data_uJ = hdul[0].data[0]
    data = data_uJ/1000 #mJ/beam
    hdr = hdul[0].header
    dlt_N_deg = abs(hdr['CDELT1'])
    dlt_n_deg = abs(hdr['CDELT2'])
    N = hdr['NAXIS1']
    n = hdr['NAXIS2']
    nu_data = hdr['CRVAL3']
    nu_BW = hdr['CDELT3']
    HPBW_deg = hdr['BMIN']
    return data, dlt_N_deg, dlt_n_deg, N, n, HPBW_deg, nu_data, nu_BW 

def make_coords(N, n, dlt_N, dlt_n, loc='centered'):
    if loc=='centered':
        ax_N_unit = np.linspace(-(N-1)/2, (N-1)/2, N)
        ax_n_unit = np.linspace(-(n-1)/2, (n-1)/2, n)
    elif loc=='edges':
        ax_N_unit = np.linspace(-N/2, N/2, N+1)
        ax_n_unit = np.linspace(-n/2, n/2, n+1)
    return dlt_N*ax_N_unit, dlt_n*ax_n_unit

def gen_fake_data(beam_cut, frac, sigma_rms, sigma_BW, N, n, dlt_N, dlt_n):
    num_beams = beam_cut+1
    
    #create coords for data
    ax_N, ax_n = make_coords(N, n, dlt_N, dlt_n)
    AX_N, AX_n = np.meshgrid(ax_N, ax_n)
    
    #create coords for sources
    dlt_N_source = dlt_N/frac
    dlt_n_source = dlt_N_source
    fov_N = N*dlt_N
    print('fov N: ' + str(fov_N))
    fov_n = n*dlt_n
    print('fov n: ' + str(fov_n))
    fov_N_source = fov_N+2*num_beams*sigma_BW
    print('fov N source: ' + str(fov_N_source))
    fov_n_source = fov_n+2*num_beams*sigma_BW
    print('fov n source: ' + str(fov_n_source))
    N_source = int(np.round(fov_N_source/dlt_N_source))
    print('N source: ' + str(N_source))
    n_source = int(np.round(fov_n_source/dlt_n_source))
    print('n source: ' + str(n_source))
    fov_N_source = N_source*dlt_N_source
    fov_n_source = n_source*dlt_n_source
    ax_N_source, ax_n_source = make_coords(N_source, n_source, dlt_N_source, dlt_n_source)
    AX_N_SOURCE, AX_n_SOURCE = np.meshgrid(ax_N_source, ax_n_source)
    #smaller rms noise in the central lxb region where l and b are in degrees
    l = 2/3
    b = 2/3
    outside = np.logical_or(np.abs(AX_N_SOURCE)>(l/2)*np.pi/180, np.abs(AX_n_SOURCE)>(b/2)*np.pi/180)
    inside = np.logical_not(outside)
    noise = sigma_rms[-1]*outside + sigma_rms[0]*inside
    #generate fake data
    z = np.random.normal(size=(n_source, N_source))
    data_gen = 0*AX_N
    for i in range(n_source):
        for j in range(N_source):
            loc = (ax_n_source[i], ax_N_source[j])
            start_N = np.searchsorted(ax_N, loc[1]-beam_cut*sigma_BW, side='left')
            end_N = np.searchsorted(ax_N, loc[1]+beam_cut*sigma_BW, side='left')
            start_n = np.searchsorted(ax_n, loc[0]-beam_cut*sigma_BW, side='left')
            end_n = np.searchsorted(ax_n, loc[0]+beam_cut*sigma_BW, side='left')
            beam = dlt_N_source*noise[i,j]/(np.sqrt(np.pi)*sigma_BW)*z[i, j] \
                *np.exp(-((AX_N[start_n:end_n, start_N:end_N]-ax_N_source[j])**2+(AX_n[start_n:end_n, start_N:end_N]-ax_n_source[i])**2)/(2*sigma_BW**2))
            data_gen[start_n:end_n, start_N:end_N] += beam
    return data_gen, AX_N, AX_n

def gen_templates(run, nu, Omega_beam, AX_N, AX_n, test_conv=False):
    #get shape of map
    n, N = AX_N.shape
    
    #bring in variables from the run
    txt_file_name = run['file_name']
    nx = run['nx']
    nnu = run['nnu']
    ny = run['ny']
    thxrange=run['thx_range']
    thyrange=run['thy_range']
    sigmav_bench = run['sigma_v']
    nu_range = run['nu_range']
    astro_model = run['Astrophysical Model']
    am = __import__(astro_model)
    
    #process run variables
    array_file_name = txt_file_name.split('_info')[0] + '.npy'
    m = re.search('[0-9]{4}_', array_file_name)
    out_type = array_file_name.split('.npy')[0].split(m.group(0))[-1]
    
    #set coordinates for synchrotron spectrum
    nuv = np.logspace(np.log10(nu_range[0]), np.log10(nu_range[1]), nnu)
    thx_full = np.linspace(-thxrange, thxrange, 2*nx)
    thy_full = np.linspace(-thyrange, thyrange, 2*ny)
    thxv = thx_full[nx:]
    thyv = thy_full[ny:]
    thx2d, thy2d = np.meshgrid(thxv, thyv)
    thx3d = np.repeat(np.array([thx2d]), nnu, axis=0)
    thy3d = np.repeat(np.array([thy2d]), nnu, axis=0)
    nu3d = np.multiply.outer(nuv, np.ones((ny, nx)))
    
    #load synchrotron emission result
    dSdnudOmega = np.load(base_path + out_type + '/' + array_file_name) #erg cm^-2 s^-1 Sr^-1
    flux_beam = ((10**26/nu3d)*dSdnudOmega*Omega_beam).astype(np.float64)
    
    #determine central fequency
    ind_nu = np.where(np.min(np.abs(nuv-nu))==np.abs(nuv-nu))[0][0]
    if test_conv:
        #replace 0s with 1e-300
        nu_fin_ind = nnu
        #find max synch frequency index and extrapolate to rho=0
        for i in range(flux_init.shape[0]):
            zs = np.where(flux_init[i] == 0)
            if len(zs[0]) == nx*ny:
                nu_fin_ind = i #max frequency index + 1
                break
            else:
                for iy, ix in zip(zs[0], zs[1]):
                    flux_init[i, iy, ix] = 1e-300
        #copy results of analysis into other quadrants
        flux_init = flux_beam
        flux_flipx = np.flip(flux_init, axis=2)
        flux_new = np.concatenate((flux_flipx, flux_init), axis=2)
        flux_flipy = np.flip(flux_new, axis=1)
        flux = np.concatenate((flux_flipy, flux_new), axis=1)
        
        #Interpolate every frequency with respect to x and y
        lnflux_interp = [interpolate.interp2d(thx_full, thy_full, np.log(f), kind='cubic') for f in flux]
        
        #Convolve with gaussian beam for a few pixels and all frequencies
        #Interpolate with respect to nu for each spatial pixel that is computed at last step.
        #Convolve with gaussian in frequency for each of these pixels
        #Store x,y interpolation at the central frequency with a standard name
    else:
        #Do all of this for central frequency only
        flux_init = flux_beam[ind_nu]
        
        #copy results of analysis into other quadrants
        flux_flipx = np.flip(flux_init, axis=1)
        flux_new = np.concatenate((flux_flipx, flux_init), axis=1)
        flux_flipy = np.flip(flux_new, axis=0)
        flux = np.concatenate((flux_flipy, flux_new), axis=0)
        
        #Interpolate with respect to x and y
        lnflux_interp = interpolate.interp2d(thx_full, thy_full, np.log(flux), kind='cubic')
    return np.exp(lnflux_interp(AX_N[0], AX_n[:, 0]))

def sort_runs(mx_set, D0_set, args=None, rtrn='inds'):
    D0_vals = np.sort(np.unique(D0_set))
    ind_set = []
    for D0_val in D0_vals:
        ind_D0val = np.where(D0_set==D0_val)[0]
        p_D0val = np.argsort(mx_set[ind_D0val])
        ind_set.append(ind_D0val[p_D0val])
    ind_set_tup = tuple(ind_set)
    ind_full = np.hstack(ind_set_tup)
    if rtrn == 'inds':
        return ind_full
    elif rtrn == 'arrs':
        if args==None:
            return mx_set[ind_full], D0_set[ind_full]
        else:
            return mx_set[ind_full], D0_set[ind_full], tuple(args[i][ind_full] for i in range(len(args)))
        
#coords = (x, y)                                                                                                                                          
#ellipse_params = (r, a, thickness/2)  
def create_mask(THETA, th_range, ps_ind=None, rl=None, coords=None, ellipse_params=None, data=None,  sigma_rms=None, num_sigma_rms=None, sigma_BW=None, num_sigma_BW=None, dlt=None,\
 method='azimuthally_sym'):
    m0 = 0*THETA==0
    m1 = m0
    m2 = m0
    m3 = m0
    if ps_ind is not None:
        m0[ps_ind]=False
    if method=='azimuthally_sym':
        m1 = np.logical_and(THETA>th_range[0], THETA<th_range[1])
    elif method=='ellipse_and_azimuthally_sym':
        m1 = np.logical_and(THETA>th_range[0], THETA<th_range[1])
        elliptic_d = np.sqrt(coords[0]**2+(ellipse_params[0]**2)*coords[1]**2)
        m2 = np.abs(elliptic_d-ellipse_params[1])>ellipse_params[2]
    elif method == 'ellipse_azimuthallysym_outside':
        m1 = np.logical_and(THETA>th_range[0], THETA<th_range[1])
        elliptic_d = np.sqrt(coords[0]**2+(ellipse_params[0]**2)*coords[1]**2)
        m2 = elliptic_d-ellipse_params[1]<-ellipse_params[2]
    elif method == 'ellipse_azimuthallysym_inside':
        m1 = np.logical_and(THETA>th_range[0], THETA<th_range[1])
        elliptic_d = np.sqrt(coords[0]**2+(ellipse_params[0]**2)*coords[1]**2)
        m2 = elliptic_d-ellipse_params[1]>-ellipse_params[2]
    if rl=='right':
        m3[np.where(AX_N>=0)] = False
    elif rl=='left':
        m3[np.where(AX_N<=0)] = False
    return m0*m1*m2*m3

def f_b0(x, w):
    return w*np.ones(x[0].shape)

def f_b1(x, w):
    elliptic_d = np.sqrt(x[0]**2+w[1]**2*x[1]**2)
    return w[0]*np.exp(-(elliptic_d-w[2])**2/(2*w[3]**2))

def f(x, w):
    return f_b0(x, w[0]) + f_b1(x, w[1:])

def chi2(w, *args):
    model = f(args[1], w)
    return np.sum(((args[0]-model)**2/args[2]**2)*args[3])

def find_test_stats(resid, signal, background, sigma_rms, mask, this_ws, this_dw, this_chi_sb_sb, sigmav, sigmav_bench=2.2e-26):
    this_w0b = this_ws
    this_chi_b_b = this_chi_sb_sb
    this_w0s = this_ws+(sigmav/sigmav_bench)*this_dw
    this_wb = this_ws-(sigmav/sigmav_bench)*this_dw
    this_chi_b_sb = np.sum(mask*(resid+(sigmav/sigmav_bench)*signal-this_w0s*background)**2/(sigma_rms**2))
    this_chi_sb_b = np.sum(mask*(resid-(sigmav/sigmav_bench)*signal-this_wb*background)**2/(sigma_rms**2))
    this_delta_chi_b = this_chi_sb_b-this_chi_b_b
    this_delta_chi_sb = this_chi_sb_sb-this_chi_b_sb 
    return this_ws, this_w0b, this_w0s, this_wb, this_chi_sb_b, this_chi_b_sb, this_delta_chi_b, this_delta_chi_sb

def remove_ps(data, THETA, cent, ann1, ann2, thresh):
    #find center index
    ind0 = np.where(THETA==0)
    indy0 = ind0[0][0]
    indx0 = ind0[1][0]

    #find indices of annulus
    ind_ann0 = np.where(np.logical_and(THETA>ann1, THETA<ann2))
    dlt_ind_ann = (ind_ann0[0]-indy0, ind_ann0[1]-indx0)

    #find indices of center
    ind_cent0 = np.where(THETA<cent)
    dlt_ind_cent = (ind_cent0[0]-indy0, ind_cent0[1]-indx0)
    
    #prepare for for-loops
    sh = data.shape
    mask_indx = []
    mask_indy = []
    
    #iterate over each pixel, putting the circle and annulus centered over the pixel and computing the average
    #intensity in each. If the circle has an average intensity larger than the annulus by a certain amount
    #then store the indices of the circle for masking
    for i in range(sh[0]):
        #print('i: ', i)
        for j in range(sh[1]):
            ind_of_ind = [k for k in range(len(dlt_ind_ann[0])) \
                                  if j+dlt_ind_ann[1][k] < N and j+dlt_ind_ann[1][k] >= 0\
                                 and i+dlt_ind_ann[0][k] < n and i+dlt_ind_ann[0][k] >= 0]
            ind_ann_x = [int(j+dlt_ind_ann[1][ind]) for ind in ind_of_ind]
            ind_ann_y = [int(i+dlt_ind_ann[0][ind]) for ind in ind_of_ind]
            num_ann = len(ind_of_ind)

            ind_of_ind_cent = [k for k in range(len(dlt_ind_cent[0])) \
                                  if j+dlt_ind_cent[1][k] < N and j+dlt_ind_cent[1][k] >= 0\
                                 and i+dlt_ind_cent[0][k] < n and i+dlt_ind_cent[0][k] >= 0]
            ind_cent_x = [int(j+dlt_ind_cent[1][ind]) for ind in ind_of_ind_cent]
            ind_cent_y = [int(i+dlt_ind_cent[0][ind]) for ind in ind_of_ind_cent]
            num_cent = len(ind_of_ind_cent)

            #compute average intensity in annulus and center
            I_center = np.sum(data[(ind_cent_y, ind_cent_x)])/num_cent
            I_ann = np.sum(data[(ind_ann_y, ind_ann_x)])/num_ann

            if I_center > thresh[i,j]+I_ann: #or I_center < I_ann-thresh[i,j]: (include if voids should be masked)
                mask_indy += list(ind_cent_y)
                mask_indx += list(ind_cent_x)
                
    #remove repeated pairs of indices from the list of indices
    mask_inds_raw = np.array([mask_indy, mask_indx])
    print('raw indices found')
    mask_inds = np.unique(mask_inds_raw, axis=1)
    
    #plot data with masked indices indicated with scatter points
    #plt.imshow(data)
    #plt.scatter(mask_inds[1], mask_inds[0], s=2, color='r')
    
    return tuple(mask_inds)

def latex_float(f, n):
    kwrd = '{0:.' +str(n)+ 'g}'
    float_str = kwrd.format(f)
    if "e" in float_str:
        base, exponent = float_str.split("e")
        return r"{0} \times 10^{{{1}}}".format(base, int(exponent))
    else:
        return float_str

# %%
#extract info about data
data, dlt_N_deg, dlt_n_deg, N, n, HPBW_deg, nu_data, nu_BW = get_data_and_info(fits_path, fits_name)
dlt_N = dlt_N_deg*np.pi/180
dlt_n = dlt_n_deg*np.pi/180
HPBW = HPBW_deg*np.pi/180
sigma_BW = HPBW/(2*np.sqrt(2*np.log(2)))
omega_beam = 2*np.pi*sigma_BW**2
print('real data info extracted')
# Out:
# real data info extracted

# %%
#create coords for data
ax_N, ax_n = make_coords(N, n, dlt_N, dlt_n)
AX_N, AX_n = np.meshgrid(ax_N, ax_n)
THETA = np.sqrt(AX_N**2+AX_n**2)
sigma_rms = [0.25, 0.3]
l = 2/3
b = 2/3
outside = np.logical_or(np.abs(AX_N)>(l/2)*np.pi/180, np.abs(AX_n)>(b/2)*np.pi/180)
inside = np.logical_not(outside)
noise = sigma_rms[-1]*outside + sigma_rms[0]*inside
rl_mask = ''

# %%
#define dimensionless hyperparams
dless_rad0 = .75
dless_rad1 = 2.25
dless_rad2 = 2.5
num_sigmas = 4

#compute physical hyperparams
cent = dless_rad0*HPBW/2
ann1 = dless_rad1*HPBW/2
ann2 = dless_rad2*HPBW/2
thresh = num_sigmas*noise

mask_inds = remove_ps(data, THETA, cent, ann1, ann2, thresh)
# Out:
# raw indices found

# %%
DA = 785
omega_pix = dlt_N*dlt_n
pix_per_beam = omega_beam/omega_pix
min_pix = pix_per_beam
this_mask = create_mask(THETA, [0, np.pi], ps_ind=mask_inds, coords=(AX_N, AX_n))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.imshow(ma.array(data, mask=np.logical_not(this_mask)), extent=[ax_N[0]*DA, ax_N[-1]*DA, ax_n[0]*DA, ax_n[-1]*DA], vmin=np.min(data), vmax = np.max(data))
plt.xlabel(r'$x \; \rm{(kpc)}$', size=14)
plt.ylabel(r'$y \; \rm{(kpc)}$', size=14)
plt.title(r'Intensity Map with Point-Source Mask', size=14)
cbar = plt.colorbar(orientation='horizontal')
cbar.set_label(r'$\rm{mJy/beam}$', size=16)
plt.savefig(base_path+'figs/intensity_map_w_ps_mask.pdf')
num_bins = 100
th_bins = np.linspace(0, np.max(THETA), num_bins+1)
flux_bin = np.zeros(num_bins)
pix_bin = np.zeros(num_bins)
er_flux = np.zeros(num_bins)
for i in range(num_bins):
    bool_bin = np.logical_and(THETA>=th_bins[i], THETA<th_bins[i+1])
    pix_bin[i] = np.sum(bool_bin*this_mask)
    flux_bin[i] = np.sum(data*bool_bin*this_mask)

er_ring = np.array([np.sqrt(pix_bin[i]/pix_per_beam)*(np.sum(noise*bool_bin*this_mask)/pix_bin[i]) if not pix_bin[i]==0 else 0 \
           for i in range(num_bins)])
mean_bin = np.array([flux_bin[i]/pix_bin[i] if not pix_bin[i]<min_pix else 0 for i in range(num_bins)])
er_beam = np.array([er_ring[i]*(pix_per_beam/pix_bin[i]) if not pix_bin[i]<min_pix else 0 for i in range(num_bins)])
fig = plt.figure()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.scatter(th_bins[0:-1]*DA, mean_bin, s=4)
plt.errorbar(th_bins[0:-1]*DA, mean_bin, yerr=er_beam, fmt='none')
ax = plt.gca()
ax.set_ylim([-0.75, 0.75])
plt.xlabel(r'$\rho \; \rm{(kpc)}$', size=16)
plt.ylabel(r'$\frac{dS_{ave}}{d\omega}\; \rm{(mJy/beam)}$', size=16)
plt.title(r'Annulus-Averaged Flux', size=16)
ax.set_box_aspect(1)
#plt.savefig(base_path + 'figs/annulus_averaged_flux.pdf')
min_ind = np.where(np.min(mean_bin) == mean_bin)[0][0] 
th_mask = th_bins[min_ind]
print(th_mask)
# Out:
# 0.0011865336088032082

# %%
th_min = th_mask
#th_min = 0
th_max = np.pi
th_range_in = [th_min, th_max]
base_mask = create_mask(THETA, th_range_in, ps_ind=mask_inds, rl=rl_mask)
plt.imshow(base_mask)
ma_data= ma.array(data, mask=np.logical_not(base_mask))
minmin = np.min(data)
maxmax = np.max(data)
fig = plt.figure()
plt.imshow(data, vmin=minmin, vmax=maxmax)
plt.colorbar(orientation='horizontal')
#plt.savefig(base_path+'figs/real_data.pdf')
fig = plt.figure()
plt.imshow(ma_data, extent=[ax_N[0]*DA, ax_N[-1]*DA, ax_n[0]*DA, ax_n[-1]*DA], vmin=minmin, vmax=maxmax)
plt.xlabel(r'$x \; \rm{(kpc)}$', size=14)
plt.ylabel(r'$y \; \rm{(kpc)}$', size=14)
plt.title(r'Intensity Map with Point-Source and Center Mask', size=14)
cbar = plt.colorbar(orientation='horizontal')
cbar.set_label(r'$\rm{mJy/beam}$', size=16)
#plt.savefig(base_path+'figs/ps_center_masked_data.pdf')

# %%
#zeroth order fit of ellipse
w_init = np.array([0,  1,  4,  0.015, 3e-3])
print('initial values of the model params are: ', w_init)
#plt.imshow(ma.array(f([AX_N, AX_n], w_init), mask=np.logical_not(this_mask)))

#print initial statistics
this_chi2 = chi2(w_init, *(data, [AX_N, AX_n],  noise, base_mask))
statement1 = 'initial weights are: '
for j in range(len(w_init)):
    statement1 += 'w' + str(j) + ' = ' + str(w_init[j]) + '; '
print(statement1)
print('chi^2 = ' + str(this_chi2))

# update weights
bnds = [(-1, 1), (0, 2), (3, 5), (.01 , 0.02), (1e-3, 1e-2)]
res = minimize(chi2, w_init, args=(data, [AX_N, AX_n], noise, base_mask), bounds=bnds)

w_fin = res.x
print('w_fin: ', w_fin)
print(res.success)
print(res.message)
chi2_final = chi2(w_fin, *(data, [AX_N, AX_n], noise, base_mask))
print('final chi2: '+ str(chi2_final)) 
fig = plt.figure()
new_model = f([AX_N, AX_n], w_fin)
model_ma = ma.array(new_model, mask=np.logical_not(base_mask))
plt.imshow(model_ma, extent=[ax_N[0]*DA, ax_N[-1]*DA, ax_n[0]*DA, ax_n[-1]*DA], vmin=minmin, vmax=maxmax) 
plt.xlabel(r'$x \; \rm{(kpc)}$', size=14)
plt.ylabel(r'$y \; \rm{(kpc)}$', size=14)
plt.title(r'Ellipse Plus Uniform Model Best Fit', size=14)
cbar = plt.colorbar(orientation='horizontal')
cbar.set_label(r'$\rm{mJy/beam}$', size=16)
#plt.savefig(base_path+'figs/best_annulus_model.pdf')
fig = plt.figure()
plt.imshow(ma_data, vmin=minmin, vmax=maxmax)
plt.colorbar(orientation='horizontal')
# Out:
# initial values of the model params are:  [0.0e+00 1.0e+00 4.0e+00 1.5e-02 3.0e-03]
# initial weights are: w0 = 0.0; w1 = 1.0; w2 = 4.0; w3 = 0.015; w4 = 0.003;
# chi^2 = 214702.81527259506
# w_fin:  [-1.37722367e-01  1.11281542e+00  4.20050018e+00  1.41995042e-02
#   3.70670747e-03]
# True
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# final chi2: 187455.5102155168

# %%
#first order fit of ellipse
#find ellipse shape while masking everything more than 2\sigma from the peak of the zeroth order ellipse on the inside

w_init = np.array(w_fin)
print('initial values of the model params are: ', w_init)
#plt.imshow(ma.array(f([AX_N, AX_n], w_init), mask=np.logical_not(this_mask)))
ell_params = list(w_fin[1:]).copy()
inside_mask = create_mask(THETA, th_range_in, ps_ind=mask_inds, coords=(AX_N, AX_n), ellipse_params=[ell_params[1], ell_params[2], ell_params[3]], \
                        method='ellipse_azimuthallysym_inside', rl=rl_mask)
#print initial statistics
this_chi2 = chi2(w_init, *(data, [AX_N, AX_n],  noise, inside_mask))
statement1 = 'initial weights are: '
for j in range(len(w_init)):
    statement1 += 'w' + str(j) + ' = ' + str(w_init[j]) + '; '
print(statement1)
print('chi^2 = ' + str(this_chi2))

# update weights
bnds = [(-1, 2), (0, 2), (3, 5), (.01 , 0.02), (1e-3, 1e-2)]
res = minimize(chi2, w_init, args=(data, [AX_N, AX_n], noise, inside_mask), bounds=bnds)

w_fin2 = res.x
print('w_fin: ', w_fin2)
print(res.success)
print(res.message)
chi2_final = chi2(w_fin2, *(data, [AX_N, AX_n], noise, inside_mask))
print('final chi2: '+ str(chi2_final)) 
fig = plt.figure()
new_model = f([AX_N, AX_n], w_fin2)
model_ma = ma.array(new_model, mask=np.logical_not(inside_mask))
plt.imshow(model_ma, extent=[ax_N[0]*DA, ax_N[-1]*DA, ax_n[0]*DA, ax_n[-1]*DA], vmin=minmin, vmax=maxmax) 
plt.xlabel(r'$x \; \rm{(kpc)}$', size=14)
plt.ylabel(r'$y \; \rm{(kpc)}$', size=14)
plt.title(r'Ellipse Plus Uniform Model Best Fit', size=14)
cbar = plt.colorbar(orientation='horizontal')
cbar.set_label(r'$\rm{mJy/beam}$', size=16)
#plt.savefig(base_path+'figs/best_annulus_model.pdf')
fig = plt.figure()
plt.imshow(ma_data, vmin=minmin, vmax=maxmax)
plt.colorbar(orientation='horizontal')
# Out:
# initial values of the model params are:  [-1.37722367e-01  1.11281542e+00  4.20050018e+00  1.41995042e-02
#   3.70670747e-03]
# initial weights are: w0 = -0.13772236680047584; w1 = 1.1128154191206483; w2 = 4.200500177559917; w3 = 0.014199504167141901; w4 = 0.0037067074709742813;
# chi^2 = 143785.84533806835
# w_fin:  [9.11027164e-02 9.23830510e-01 4.20797892e+00 1.38224019e-02
#  3.02989447e-03]
# True
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# final chi2: 137997.9615693217

# %%
mode = 'load'
starting_sample = 0
num_samples = 200
ell_params2 = list(w_fin2[1:])

# %%
#prepare sets of sigmav mx and D0
frac = 2.7
beam_cut = 5
sig_type = 2
sigmav_bench = 2.2e-26
mx_start = 6
mx_stop = 500
num_mx = 20
sigmav_start = -27
sigmav_end = -23
num_sigmav = 80
mask_thick_dless = np.array([1])
num_masks = len(mask_thick_dless)

#make these be  in increasing order
#D0_set_in = np.array([5e27, 1.1e28, 5e28, 2e29])
D0_set_in = np.array([3e27, 3e28, 3e29])
mx_set_in = np.round(np.logspace(np.log10(mx_start), np.log10(mx_stop), num_mx), 1)
sigmav_ar = np.logspace(sigmav_start, sigmav_end, num_sigmav)

# %%
#create masks
rl_mask = ''
mask_set=[]
for thickness in mask_thick_dless:
    this_mask = create_mask(THETA, th_range_in, ps_ind=mask_inds, coords=(AX_N, AX_n), ellipse_params=[ell_params[1], ell_params[2], ell_params[3]], \
                        method='ellipse_azimuthallysym_outside', rl=rl_mask)
    mask_set.append(this_mask)
mask_set = np.array(mask_set)
print(th_range_in)
plt.imshow(mask_set[0])
# Out:
# [0.0011865336088032082, 3.141592653589793]

# %%
#extract info of runs that match criteria
run_list = mt.find_results(sig_type, astro_model='Andromeda1', spherical_ave='weighted_dl', D0=D0_set_in, mx=mx_set_in)
num_runs = len(run_list)
print('length of run_list: ', str(num_runs))
signal_temp_set = []
mx_set_out = []
D0_set_out = []
for run in run_list:
    print(run)
    mx_set_out.append(run['mx'])
    D0_set_out.append(run['D0'])
    this_signal_temp = gen_templates(run, nu_data, omega_beam, AX_N, AX_n)
    signal_temp_set.append(this_signal_temp)
mx_set_out = np.array(mx_set_out)
D0_set_out = np.array(D0_set_out)
signal_temp_set = np.array(signal_temp_set)

#sort runs
ind = sort_runs(mx_set_out, D0_set_out)
mx_set_out = mx_set_out[ind]
D0_set_out = D0_set_out[ind]
signal_temp_set = signal_temp_set[ind]
run_list = [run_list[i] for i in ind]
# Out:
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# 0.017
# length of run_list:  120
# {'file_name': '0121_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0122_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0123_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0124_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0125_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0126_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0127_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0128_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0129_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0130_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0131_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0132_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0133_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0134_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0135_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0136_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0137_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0138_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0139_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0140_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0141_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0142_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0143_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0144_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0145_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0146_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0147_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0148_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0149_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0150_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0151_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0152_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0153_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0154_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0155_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0156_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0157_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0158_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0159_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0160_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0161_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0162_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0163_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0164_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0165_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0166_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0167_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0168_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0169_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0170_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0171_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0172_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0173_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0174_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0175_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0176_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0177_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0178_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0179_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0180_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1.25; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0241_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0242_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0243_synchrotron_emission_info.txt', 'mx': 6.0, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0244_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0245_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0246_synchrotron_emission_info.txt', 'mx': 7.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0247_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0248_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0249_synchrotron_emission_info.txt', 'mx': 9.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0250_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0251_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0252_synchrotron_emission_info.txt', 'mx': 12.1, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0253_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0254_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0255_synchrotron_emission_info.txt', 'mx': 15.2, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0256_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0257_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0258_synchrotron_emission_info.txt', 'mx': 19.2, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0259_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0260_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0261_synchrotron_emission_info.txt', 'mx': 24.3, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0262_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0263_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0264_synchrotron_emission_info.txt', 'mx': 30.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0265_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0266_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0267_synchrotron_emission_info.txt', 'mx': 38.6, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0268_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0269_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0270_synchrotron_emission_info.txt', 'mx': 48.8, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0271_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0272_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0273_synchrotron_emission_info.txt', 'mx': 61.5, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0274_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0275_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0276_synchrotron_emission_info.txt', 'mx': 77.7, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0277_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0278_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0279_synchrotron_emission_info.txt', 'mx': 98.0, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0280_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0281_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0282_synchrotron_emission_info.txt', 'mx': 123.7, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0283_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0284_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0285_synchrotron_emission_info.txt', 'mx': 156.1, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0286_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0287_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0288_synchrotron_emission_info.txt', 'mx': 197.1, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0289_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0290_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0291_synchrotron_emission_info.txt', 'mx': 248.7, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0292_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0293_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0294_synchrotron_emission_info.txt', 'mx': 313.9, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0295_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0296_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0297_synchrotron_emission_info.txt', 'mx': 396.2, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0298_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+27, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0299_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+28, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}
# {'file_name': '0300_synchrotron_emission_info.txt', 'mx': 500.0, 'D0': 3e+29, 'channel': 'bb_bar', 'nr': 800, 'nE': 400, 'sigma_v': 2.2e-26, 'DM_model': 'model type- NFW; rho0- 0.43GeV/cm^3; gamma- 1; Scale Radius- 16.5kpc; ', 'Astrophysical Model': 'Andromeda1', 'Spherical Average': 'weighted_dl', 'nx': 58, 'ny': 20, 'nnu': 3, 'thx_range': 0.017, 'thy_range': 0.006, 'nu_range': [5050000000.0, 11650000000.0], 'nu_spacing': 'lin'}

# %%
#initialize arrays
dchi2_sb = np.zeros((num_masks, num_runs, num_sigmav, num_samples+1))
dchi2_b = np.zeros((num_masks, num_runs, num_sigmav, num_samples+1))

# %%
#compute quantities that do not need to be recalculated for each image
#isotropic background template
b0 = np.ones((n,N))
unit_wfin2 = np.copy(w_fin2)
unit_wfin2[0] = 0
unit_wfin2[1] = 1
b1 = f([AX_N, AX_n], unit_wfin2)

P0 = (np.repeat(np.array([b0]), num_masks, axis=0) - np.multiply.outer((np.sum(mask_set*b0*b1/noise**2, axis=(1,2))/np.sum(mask_set*b1*b1/noise**2, axis=(1,2))), b1))\
/np.repeat(np.array([np.sum(mask_set*b0*b0/noise**2, axis=(1,2)) - np.sum(mask_set*b0*b1/noise**2, axis=(1,2))/np.sum(mask_set*b1*b1/noise**2, axis=(1,2))]), num_masks, axis=0)

P1 = (np.repeat(np.array([b1]), num_masks, axis=0) - np.multiply.outer((np.sum(mask_set*b1*b0/noise**2, axis=(1,2))/np.sum(mask_set*b0*b0/noise**2, axis=(1,2))), b0))\
/np.repeat(np.array([np.sum(mask_set*b1*b1/noise**2, axis=(1,2)) - np.sum(mask_set*b1*b0/noise**2, axis=(1,2))/np.sum(mask_set*b0*b0/noise**2, axis=(1,2))]), num_masks, axis=0)

# #sums in dchi^2 that are independent of simulated intensity map
sum3 = np.einsum('ijk,ljk', mask_set, signal_temp_set**2/noise**2)
sum4_0 = np.sum(mask_set*b0*b0/(noise**2), axis=(1,2))
sum4_01 = np.sum(mask_set*b0*b1/(noise**2), axis=(1,2))
sum4_1 = np.sum(mask_set*b1*b1/(noise**2), axis=(1,2))
sum5_0 = 2*np.einsum('ijk,ljk', mask_set, signal_temp_set*b0/noise**2)
sum5_1 = 2*np.einsum('ijk,ljk', mask_set, signal_temp_set*b1/noise**2)

# #how much should the background models change by if we add or subtract the signals
dw0 = np.einsum('ljk,ijk', mask_set*P0, signal_temp_set/noise**2).T
dw1 = np.einsum('ljk,ijk', mask_set*P1, signal_temp_set/noise**2).T
dw0_sigmav = np.multiply.outer(dw0, sigmav_ar/sigmav_bench)
dw1_sigmav = np.multiply.outer(dw1, sigmav_ar/sigmav_bench)

#coefficients in dchi^2 that are independent of simulated intensity map. Signs on coefficeints
#are correct for dchi^2_b and some signs my need to change for dchi^2_sb
coef1_0 = 2*dw0_sigmav #sum1
coef1_1 = 2*dw1_sigmav #sum1
coef2 = -2*sigmav_ar/sigmav_bench #sum2
coef3 = (sigmav_ar/sigmav_bench)**2 #sum3; opposite sign for sb
#check signs
coef5_0 = dw0_sigmav**2 #sum4_0; opposite sign for sb
coef5_1 = dw1_sigmav**2 #sum4_1; opposite sign for sb
coef5_01 = 2*dw0_sigmav*dw1_sigmav #sum4_01; opposite sign for sb
coef7_0 = - dw0_sigmav*sigmav_ar/sigmav_bench #sum5_0; opposite sign for sb
coef7_1 = - dw1_sigmav*sigmav_ar/sigmav_bench #sum5_1; opposite sign for sb
#terms in dchi^2 that are independent of simulated intensity map. Signs are correct for 
#dchi^2_b and signs need to be flipped  for dchi^2_sb where indicated
term3 = np.multiply.outer(sum3, coef3) #opposite sign for sb
term5_0 = (coef5_0.transpose((1, 2, 0))*sum4_0).transpose((2,0,1)) #opposite sign for sb
term5_1 = (coef5_1.transpose((1, 2, 0))*sum4_1).transpose((2,0,1)) #opposite sign for sb
term5_01 = (coef5_01.transpose((1, 2, 0))*sum4_01).transpose((2,0,1)) #opposite sign for sb
term7_0 = (coef7_0.transpose((2, 0, 1))*sum5_0).transpose((1, 2, 0)) #opposite_sign for sb
term7_1 = (coef7_1.transpose((2, 0, 1))*sum5_1).transpose((1, 2, 0)) #opposite_sign for sb

# %%
for i in range(num_samples+1):
    if i<num_samples:
        print('starting to generate sample number ' + str(i))
        #generate fake data residuals                                                                                                                                                       
        file_name_base = base_path + 'fake_resid_new/sigma_rms_'+ str(sigma_rms[0]) + '_' + \
                         str(sigma_rms[-1]) + '_spacing_' + '{:.2e}'.format(dlt_N/frac) + '_samplenum_'
        file_name=file_name_base+str(i+starting_sample) + '.npy'
        if mode == 'save' or mode == 'none':
            data_resid, _, _ = gen_fake_data(beam_cut, frac, sigma_rms_vals, sigma_BW, N, n, dlt_N, dlt_n)
            if mode == 'save':
                np.save(file_name, data_resid)
            print('sample number '+ str(starting_samples[0]+i) + ' generated')
        elif mode == 'load':
            data_resid = np.load(file_name)
        else:
            print('value mode is not recognized')
        #add residuals to best fit ring model                                                                                                                                               
        w_sim = [0] + ell_params2
        fake_bmap = data_resid  + f([AX_N, AX_n], w_sim) 
    else:
        #on the last iteration, use real data
        fake_bmap = data

    this_w0sb_sb = np.sum(mask_set*P0*fake_bmap/noise**2, axis=(1,2))
    this_w1sb_sb = np.sum(mask_set*P1*fake_bmap/noise**2, axis=(1,2))

    sum1_0 = np.sum(mask_set*fake_bmap*b0/noise**2, axis=(1,2))
    sum1_1 = np.sum(mask_set*fake_bmap*b1/noise**2, axis=(1,2))
    
    sum2 = np.einsum('ijk,ljk', mask_set*fake_bmap/(noise**2) , signal_temp_set)

    coef4_0 = -2*(dw0_sigmav.transpose((1, 2, 0))*this_w0sb_sb).transpose((2,0,1))#sum4
    coef4_1 = -2*(dw1_sigmav.transpose((1, 2, 0))*this_w1sb_sb).transpose((2,0,1))#sum4
    coef4_01 = -2*(dw0_sigmav.transpose((1, 2, 0))*this_w1sb_sb).transpose((2,0,1))#sum4
    coef4_10 = -2*(dw1_sigmav.transpose((1, 2, 0))*this_w0sb_sb).transpose((2,0,1))#sum4
    #(wait to assemble coef6 until combining it with sum5)

    term1_0 = (coef1_0.transpose((1,2,0))*sum1_0).transpose((2,0,1))
    term1_1 = (coef1_1.transpose((1,2,0))*sum1_1).transpose((2,0,1))
    term2 = np.multiply.outer(sum2, coef2)
    term4_0 = (coef4_0.transpose((1, 2, 0))*sum4_0).transpose((2,0,1))
    term4_1 = (coef4_1.transpose((1, 2, 0))*sum4_1).transpose((2,0,1))
    term4_01 = ((coef4_10 + coef4_01).transpose((1, 2, 0))*sum4_01).transpose((2,0,1))
    term6_0 = np.multiply.outer(((sum5_0.T*this_w0sb_sb).T), sigmav_ar/sigmav_bench)
    term6_1 = np.multiply.outer(((sum5_1.T*this_w1sb_sb).T), sigmav_ar/sigmav_bench)

    this_dchi2_b = term1_0 + term1_1 + term2 + term3 + term4_0 + term4_1 + term4_01 + term5_0 + term5_1 + term5_01 \
    + term6_0 + term6_1 + term7_0 + term7_1
    
    this_dchi2_sb = term1_0 + term1_1 + term2 - term3 + term4_0 + term4_1 + term4_01 - term5_0 - term5_1 - term5_01 \
    + term6_0 + term6_1 - term7_0 - term7_1
    
    dchi2_b[:, : , :, i] = this_dchi2_b
    dchi2_sb[:, : , :, i] = this_dchi2_sb
# Out:
# starting to generate sample number 0
# starting to generate sample number 1
# starting to generate sample number 2
# starting to generate sample number 3
# starting to generate sample number 4
# starting to generate sample number 5
# starting to generate sample number 6
# starting to generate sample number 7
# starting to generate sample number 8
# starting to generate sample number 9
# starting to generate sample number 10
# starting to generate sample number 11
# starting to generate sample number 12
# starting to generate sample number 13
# starting to generate sample number 14
# starting to generate sample number 15
# starting to generate sample number 16
# starting to generate sample number 17
# starting to generate sample number 18
# starting to generate sample number 19
# starting to generate sample number 20
# starting to generate sample number 21
# starting to generate sample number 22
# starting to generate sample number 23
# starting to generate sample number 24
# starting to generate sample number 25
# starting to generate sample number 26
# starting to generate sample number 27
# starting to generate sample number 28
# starting to generate sample number 29
# starting to generate sample number 30
# starting to generate sample number 31
# starting to generate sample number 32
# starting to generate sample number 33
# starting to generate sample number 34
# starting to generate sample number 35
# starting to generate sample number 36
# starting to generate sample number 37
# starting to generate sample number 38
# starting to generate sample number 39
# starting to generate sample number 40
# starting to generate sample number 41
# starting to generate sample number 42
# starting to generate sample number 43
# starting to generate sample number 44
# starting to generate sample number 45
# starting to generate sample number 46
# starting to generate sample number 47
# starting to generate sample number 48
# starting to generate sample number 49
# starting to generate sample number 50
# starting to generate sample number 51
# starting to generate sample number 52
# starting to generate sample number 53
# starting to generate sample number 54
# starting to generate sample number 55
# starting to generate sample number 56
# starting to generate sample number 57
# starting to generate sample number 58
# starting to generate sample number 59
# starting to generate sample number 60
# starting to generate sample number 61
# starting to generate sample number 62
# starting to generate sample number 63
# starting to generate sample number 64
# starting to generate sample number 65
# starting to generate sample number 66
# starting to generate sample number 67
# starting to generate sample number 68
# starting to generate sample number 69
# starting to generate sample number 70
# starting to generate sample number 71
# starting to generate sample number 72
# starting to generate sample number 73
# starting to generate sample number 74
# starting to generate sample number 75
# starting to generate sample number 76
# starting to generate sample number 77
# starting to generate sample number 78
# starting to generate sample number 79
# starting to generate sample number 80
# starting to generate sample number 81
# starting to generate sample number 82
# starting to generate sample number 83
# starting to generate sample number 84
# starting to generate sample number 85
# starting to generate sample number 86
# starting to generate sample number 87
# starting to generate sample number 88
# starting to generate sample number 89
# starting to generate sample number 90
# starting to generate sample number 91
# starting to generate sample number 92
# starting to generate sample number 93
# starting to generate sample number 94
# starting to generate sample number 95
# starting to generate sample number 96
# starting to generate sample number 97
# starting to generate sample number 98
# starting to generate sample number 99
# starting to generate sample number 100
# starting to generate sample number 101
# starting to generate sample number 102
# starting to generate sample number 103
# starting to generate sample number 104
# starting to generate sample number 105
# starting to generate sample number 106
# starting to generate sample number 107
# starting to generate sample number 108
# starting to generate sample number 109
# starting to generate sample number 110
# starting to generate sample number 111
# starting to generate sample number 112
# starting to generate sample number 113
# starting to generate sample number 114
# starting to generate sample number 115
# starting to generate sample number 116
# starting to generate sample number 117
# starting to generate sample number 118
# starting to generate sample number 119
# starting to generate sample number 120
# starting to generate sample number 121
# starting to generate sample number 122
# starting to generate sample number 123
# starting to generate sample number 124
# starting to generate sample number 125
# starting to generate sample number 126
# starting to generate sample number 127
# starting to generate sample number 128
# starting to generate sample number 129
# starting to generate sample number 130
# starting to generate sample number 131
# starting to generate sample number 132
# starting to generate sample number 133
# starting to generate sample number 134
# starting to generate sample number 135
# starting to generate sample number 136
# starting to generate sample number 137
# starting to generate sample number 138
# starting to generate sample number 139
# starting to generate sample number 140
# starting to generate sample number 141
# starting to generate sample number 142
# starting to generate sample number 143
# starting to generate sample number 144
# starting to generate sample number 145
# starting to generate sample number 146
# starting to generate sample number 147
# starting to generate sample number 148
# starting to generate sample number 149
# starting to generate sample number 150
# starting to generate sample number 151
# starting to generate sample number 152
# starting to generate sample number 153
# starting to generate sample number 154
# starting to generate sample number 155
# starting to generate sample number 156
# starting to generate sample number 157
# starting to generate sample number 158
# starting to generate sample number 159
# starting to generate sample number 160
# starting to generate sample number 161
# starting to generate sample number 162
# starting to generate sample number 163
# starting to generate sample number 164
# starting to generate sample number 165
# starting to generate sample number 166
# starting to generate sample number 167
# starting to generate sample number 168
# starting to generate sample number 169
# starting to generate sample number 170
# starting to generate sample number 171
# starting to generate sample number 172
# starting to generate sample number 173
# starting to generate sample number 174
# starting to generate sample number 175
# starting to generate sample number 176
# starting to generate sample number 177
# starting to generate sample number 178
# starting to generate sample number 179
# starting to generate sample number 180
# starting to generate sample number 181
# starting to generate sample number 182
# starting to generate sample number 183
# starting to generate sample number 184
# starting to generate sample number 185
# starting to generate sample number 186
# starting to generate sample number 187
# starting to generate sample number 188
# starting to generate sample number 189
# starting to generate sample number 190
# starting to generate sample number 191
# starting to generate sample number 192
# starting to generate sample number 193
# starting to generate sample number 194
# starting to generate sample number 195
# starting to generate sample number 196
# starting to generate sample number 197
# starting to generate sample number 198
# starting to generate sample number 199

# %%
#test calculation of dchi2
dchi2_b_test = np.zeros(num_samples+1)
dchi2_sb_test = np.zeros(num_samples+1)
for i in range(num_samples+1):
    if i<num_samples:
        print('starting to generate sample number ' + str(i))
        #generate fake data residuals                                                                                                                                                       
        file_name_base = base_path + 'fake_resid_new/sigma_rms_'+ str(sigma_rms[0]) + '_' + \
                         str(sigma_rms[-1]) + '_spacing_' + '{:.2e}'.format(dlt_N/frac) + '_samplenum_'
        file_name=file_name_base+str(i+starting_sample) + '.npy'
        if mode == 'save' or mode == 'none':
            data_resid, _, _ = gen_fake_data(beam_cut, frac, sigma_rms_vals, sigma_BW, N, n, dlt_N, dlt_n)
            if mode == 'save':
                np.save(file_name, data_resid)
            print('sample number '+ str(starting_samples[0]+i) + ' generated')
        elif mode == 'load':
            data_resid = np.load(file_name)
        else:
            print('value mode is not recognized')
        #add residuals to best fit ring model                                                                                                                                               
        w_sim = [0] + ell_params2
        fake_bmap = data_resid  + f([AX_N, AX_n], w_sim) 
    else:
        #on the last iteration, use real data
        fake_bmap = data
    sv_ind = 40
    mask_ind = 0
    mx_test = 48.8
    D0_test = 1.1e28
    sigmav_test = sigmav_ar[sv_ind]
    print('sigmav test = ', sigmav_test)
    mask_test = mask_set[mask_ind]
    in_agreement = np.where(np.logical_and(D0_set_out==D0_test, mx_set_out==mx_test))[0]
    print('number in agreement: ', len(in_agreement))
    signal_ind = in_agreement[0]
    signal_temp_test = signal_temp_set[signal_ind]
    fake_bmap_s = fake_bmap + signal_temp_test
    chi_sb_sb = np.sum(mask_test*(fake_bmap_s - (sigmav_test/sigmav_bench)*signal_temp_test- w0_sbsb*b0- w1_sbsb*b1)**2/noise**2)
    chi_b_sb = np.sum(mask_test*(fake_bmap_s - w0_bsb*b0- w1_bsb*b1)**2/noise**2)
    chi_sb_b = np.sum(mask_test*(fake_bmap - (sigmav_test/sigmav_bench)*signal_temp_test- w0_sbb*b0- w1_sbb*b1)**2/noise**2)
    chi_b_b = np.sum(mask_test*(fake_bmap - w0_bb*b0- w1_bb*b1)**2/noise**2)
